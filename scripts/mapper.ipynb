# %% [markdown]
# #### Attempt to map the conditions and interventions to CURIEs

# %%
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup
import re
import collections
import os

# %%
# %pip install thefuzz
# Out:
# Collecting thefuzz
#   Using cached thefuzz-0.19.0-py2.py3-none-any.whl (17 kB)
# Installing collected packages: thefuzz
# Successfully installed thefuzz-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# for testing
data_extracted = "/Users/Kamileh/Work/ISB/NCATS_BiomedicalTranslator/Projects/ClinicalTrials/ETL_Python/data/2023-04-03_extracted"

# %%
# read in pipe-delimited files
conditions_df = pd.read_csv(data_extracted + '/conditions.txt', sep='|', index_col=False, header=0)
interventions_df = pd.read_csv(data_extracted + '/interventions.txt', sep='|', index_col=False, header=0)
browse_conditions_df = pd.read_csv(data_extracted + '/browse_conditions.txt', sep='|', index_col=False, header=0)
browse_interventions_df = pd.read_csv(data_extracted + '/browse_interventions.txt', sep='|', index_col=False, header=0)

browse_interventions_df.head()
# Out:
#          id       nct_id          mesh_term downcase_mesh_term      mesh_type
# 0  57856435  NCT00246285        Risperidone        risperidone      mesh-list
# 1  57856584  NCT04626778  Hydrogen Peroxide  hydrogen peroxide      mesh-list
# 2  57856732  NCT00219908       Mitoxantrone       mitoxantrone      mesh-list
# 3  57856807  NCT00220064           Vitamins           vitamins  mesh-ancestor
# 4  57857560  NCT04612894           Apatinib           apatinib      mesh-list

# %%
conditions_df.head()
# Out:
#          id       nct_id            name   downcase_name
# 0  31338340  NCT01819987      Overweight      overweight
# 1  31338518  NCT01821599  Rehabilitation  rehabilitation
# 2  31338693  NCT01823731  Ovarian Cancer  ovarian cancer
# 3  31338879  NCT01825850         Healthy         healthy
# 4  31339149  NCT01829022           Myoma           myoma

# %%
browse_conditions_df.head()
# Out:
#           id       nct_id    mesh_term downcase_mesh_term      mesh_type
# 0  113697939  NCT00185796     Syndrome           syndrome      mesh-list
# 1  113698103  NCT00185913    Neoplasms          neoplasms  mesh-ancestor
# 2  113698185  NCT03516604   Depression         depression      mesh-list
# 3  113698265  NCT03318952         Pain               pain  mesh-ancestor
# 4  113698420  NCT02789800  Tauopathies        tauopathies  mesh-ancestor

# %%
# every clinical trial has at least one MeSH-list (leaf), and may have 0 or more MeSH-ancestors (see MeSH analytics script)
# subset browse_conditions to get only the MeSH-list terms or leaves
condition_mesh_leaves = browse_conditions_df[browse_conditions_df["mesh_type"].str.contains("mesh-list")]
condition_mesh_leaves
# Out:
#                 id       nct_id             mesh_term    downcase_mesh_term  \
# 0        113697939  NCT00185796              Syndrome              syndrome
# 2        113698185  NCT03516604            Depression            depression
# 5        113698730  NCT00461539            Depression            depression
# 6        113698920  NCT05324137                Polyps                polyps
# 11       113700140  NCT00176514             Mucositis             mucositis
# ...            ...          ...                   ...                   ...
# 2849547  111234990  NCT00733525       Bulimia Nervosa       bulimia nervosa
# 2849551  111234994  NCT02653131  Short Bowel Syndrome  short bowel syndrome
# 2849552  111234995  NCT02653131              Syndrome              syndrome
# 2849564  111204205  NCT04834908            Infections            infections
# 2849565  111204206  NCT04834908              COVID-19              covid-19
#
#          mesh_type
# 0        mesh-list
# 2        mesh-list
# 5        mesh-list
# 6        mesh-list
# 11       mesh-list
# ...            ...
# 2849547  mesh-list
# 2849551  mesh-list
# 2849552  mesh-list
# 2849564  mesh-list
# 2849565  mesh-list
#
# [761406 rows x 5 columns]

# %%
conditions_exact_mapped = pd.merge(conditions_df[['nct_id', 'name', 'downcase_name']],
                             browse_conditions_df[['nct_id', 'mesh_term', 'downcase_mesh_term', 'mesh_type']],
                             how='left',
                             left_on=['nct_id', 'downcase_name'],
                             right_on = ['nct_id', 'downcase_mesh_term'])
                             
conditions_exact_mapped = conditions_exact_mapped.sort_values(by=['nct_id'])

# %%
conditions_unmapped = conditions_exact_mapped[conditions_exact_mapped['mesh_term'].isnull()]
conditions_unmapped
# Out:
#              nct_id                                               name  \
# 25683   NCT00000102                     Congenital Adrenal Hyperplasia
# 228818  NCT00000105                                             Cancer
# 249384  NCT00000110                                            Obesity
# 203653  NCT00000112                                           Diabetes
# 203651  NCT00000112                                            Obesity
# ...             ...                                                ...
# 472887  NCT05794061                               Psychiatric Disorder
# 472886  NCT05794061                                           Dementia
# 472885  NCT05794061                               Cognitive Impairment
# 472884  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 472883  NCT05794087                                      Air Pollution
#
#                                             downcase_name mesh_term  \
# 25683                      congenital adrenal hyperplasia       NaN
# 228818                                             cancer       NaN
# 249384                                            obesity       NaN
# 203653                                           diabetes       NaN
# 203651                                            obesity       NaN
# ...                                                   ...       ...
# 472887                               psychiatric disorder       NaN
# 472886                                           dementia       NaN
# 472885                               cognitive impairment       NaN
# 472884  nutrition deficiency (xanth deficiency) due to...       NaN
# 472883                                      air pollution       NaN
#
#        downcase_mesh_term mesh_type
# 25683                 NaN       NaN
# 228818                NaN       NaN
# 249384                NaN       NaN
# 203653                NaN       NaN
# 203651                NaN       NaN
# ...                   ...       ...
# 472887                NaN       NaN
# 472886                NaN       NaN
# 472885                NaN       NaN
# 472884                NaN       NaN
# 472883                NaN       NaN
#
# [563678 rows x 6 columns]

# %%
# find studies for which there is only 1 condition listed (from unmapped conditions)
conditions_unmapped_per_study = pd.DataFrame(conditions_unmapped.groupby("nct_id")["downcase_name"].apply(list))
conditions_unmapped_per_study
# Out:
#                                                  downcase_name
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000110                                          [obesity]
# NCT00000112                                [diabetes, obesity]
# NCT00000115                           [macular edema, cystoid]
# ...                                                        ...
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794048                [pancreatic tumor, hepatocarcinoma]
# NCT05794061  [psychiatric disorder, dementia, cognitive imp...
# NCT05794074  [nutrition deficiency (xanth deficiency) due t...
# NCT05794087                                    [air pollution]
#
# [344498 rows x 1 columns]

# %%
conditions_unmapped_per_study["condition_counts"] = conditions_unmapped_per_study["downcase_name"].str.len()
conditions_unmapped_per_study
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000110                                          [obesity]
# NCT00000112                                [diabetes, obesity]
# NCT00000115                           [macular edema, cystoid]
# ...                                                        ...
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794048                [pancreatic tumor, hepatocarcinoma]
# NCT05794061  [psychiatric disorder, dementia, cognitive imp...
# NCT05794074  [nutrition deficiency (xanth deficiency) due t...
# NCT05794087                                    [air pollution]
#
#              condition_counts
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000110                 1
# NCT00000112                 2
# NCT00000115                 1
# ...                       ...
# NCT05794035                 1
# NCT05794048                 2
# NCT05794061                 3
# NCT05794074                 1
# NCT05794087                 1
#
# [344498 rows x 2 columns]

# %%
unmapped_single_conditions = conditions_unmapped_per_study[conditions_unmapped_per_study["condition_counts"] == 1]
unmapped_single_conditions
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000110                                          [obesity]
# NCT00000115                           [macular edema, cystoid]
# NCT00000123                                           [myopia]
# ...                                                        ...
# NCT05793944                                        [pregnancy]
# NCT05794009                                 [exercise therapy]
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794074  [nutrition deficiency (xanth deficiency) due t...
# NCT05794087                                    [air pollution]
#
#              condition_counts
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000110                 1
# NCT00000115                 1
# NCT00000123                 1
# ...                       ...
# NCT05793944                 1
# NCT05794009                 1
# NCT05794035                 1
# NCT05794074                 1
# NCT05794087                 1
#
# [241959 rows x 2 columns]

# %%
mapped_single_conditions = pd.merge(unmapped_single_conditions, condition_mesh_leaves[["nct_id", "downcase_mesh_term"]], left_on=["nct_id"], right_on=["nct_id"])
with pd.option_context("display.max_rows", 1000):
    display(mapped_single_conditions[:20])
# Out:
#          nct_id                     downcase_name  condition_counts  \
# 0   NCT00000102  [congenital adrenal hyperplasia]                 1
# 1   NCT00000102  [congenital adrenal hyperplasia]                 1
# 2   NCT00000102  [congenital adrenal hyperplasia]                 1
# 3   NCT00000102  [congenital adrenal hyperplasia]                 1
# 4   NCT00000105                          [cancer]                 1
# 5   NCT00000115          [macular edema, cystoid]                 1
# 6   NCT00000115          [macular edema, cystoid]                 1
# 7   NCT00000123                          [myopia]                 1
# 8   NCT00000126       [ischemic optic neuropathy]                 1
# 9   NCT00000126       [ischemic optic neuropathy]                 1
# 10  NCT00000126       [ischemic optic neuropathy]                 1
# 11  NCT00000127       [ischemic optic neuropathy]                 1
# 12  NCT00000127       [ischemic optic neuropathy]                 1
# 13  NCT00000127       [ischemic optic neuropathy]                 1
# 14  NCT00000132             [open-angle glaucoma]                 1
# 15  NCT00000132             [open-angle glaucoma]                 1
# 16  NCT00000135                  [hiv infections]                 1
# 17  NCT00000135                  [hiv infections]                 1
# 18  NCT00000136                  [hiv infections]                 1
# 19  NCT00000136                  [hiv infections]                 1
#
#                  downcase_mesh_term
# 0   adrenal hyperplasia, congenital
# 1            adrenogenital syndrome
# 2      adrenocortical hyperfunction
# 3                       hyperplasia
# 4                           tetanus
# 5                     macular edema
# 6                             edema
# 7                       astigmatism
# 8                          ischemia
# 9              optic nerve diseases
# 10       optic neuropathy, ischemic
# 11             optic nerve diseases
# 12       optic neuropathy, ischemic
# 13                         ischemia
# 14                         glaucoma
# 15             glaucoma, open-angle
# 16        cytomegalovirus retinitis
# 17                        retinitis
# 18        cytomegalovirus retinitis
# 19                        retinitis

# %% [markdown]
# ### Conclusion: there are multiple candidate MeSH terms (leaf nodes only, not ancestors) available per 1 condition

# %% [markdown]
# # Use MetaMap to find more candidate matches

# %%
CAS_SERVERURL = "https://utslogin.nlm.nih.gov/cas/v1"
II_SKR_SERVERURL = 'https://ii.nlm.nih.gov/cgi-bin/II/UTS_Required'
METAMAP_INTERACTIVE_URL = II_SKR_SERVERURL + "/API_MM_interactive.pl"
stserverurl = "https://utslogin.nlm.nih.gov/cas/v1/tickets"
tgtserverurl = "https://utslogin.nlm.nih.gov/cas/v1/api-key"
apikey = '54041f07-fc66-4558-b038-b46ca8bdcc6b'
serviceurl = METAMAP_INTERACTIVE_URL
ksource = '2020AB'

def get_service_ticket(serverurl, ticket_granting_ticket, serviceurl):
    """ Obtain a Single-Use Proxy Ticket (also known as service ticket).
    Request for a Service Ticket:
        POST /cas/v1/tickets/{TGT id} HTTP/1.0
    data:
           service={form encoded parameter for the service url}
    Sucessful Response:
        200 OK
        ST-1-FFDFHDSJKHSDFJKSDHFJKRUEYREWUIFSD2132
    @param serverurl authentication server
    @param ticketGrantingTicket a Proxy Granting Ticket.
    @param serviceurl url of service with protected resources
    @return authentication ticket for service. """
    resp = requests.post("{}/{}".format(serverurl, ticket_granting_ticket),
                         {"service": serviceurl})
    if resp.status_code == 200:
        return resp.content
    return 'Error: status: {}'.format(resp.content)


def extract_tgt_ticket(htmlcontent):
    "Extract ticket granting ticket from HTML."
    # print('htmlcontent: {}'.format(htmlcontent))
    html = HTML(html=htmlcontent)
    # get form element
    elements = html.xpath("//form")
    # print('html response: {}'.format(etree.tostring(html.lxml).decode()))
    # print('action attribure: {}'.format(elements[0].attrs['action']))
    # extract ticket granting ticket out of 'action' attribute
    if elements != []:
        return elements[0].attrs['action'].split('/')[-1]
    else:
        return "form element missing from ticket granting ticket response"

def get_ticket(cas_serverurl, apikey, serviceurl):
    # set ticket granting ticket server url
    tgtserverurl = cas_serverurl + "/api-key"
    # set service ticket server url
    stserverurl = cas_serverurl + "/tickets"
    tgt = get_ticket_granting_ticket(tgtserverurl, apikey)
    return get_service_ticket(stserverurl, tgt, serviceurl)

def get_ticket_granting_ticket(tgtserverurl, apikey):
    # http://serviceurl/cas/v1/tickets/{TGT id}
    response = requests.post(tgtserverurl, {'apikey': apikey},
                             headers={'Accept': 'test/plain'})
    return extract_tgt_ticket(response.content)

def extract_tgt_ticket(htmlcontent):
    "Extract ticket granting ticket from HTML."    
    soup = BeautifulSoup(htmlcontent)
#     print(soup.find('form').get("action"))
    cas_url = soup.find("form").get("action")
    "Extract ticket granting ticket out of 'action' attribute"
#     tgt = cas_url.rsplit('/')[-1]
    return cas_url.rsplit('/')[-1]
    
ticket = get_ticket(CAS_SERVERURL, apikey, serviceurl)

# %%
args = ['-I -i -z -C']
form = {}
form['APIText'] = "A spinal tap was performed and oligoclonal bands were \
detected in the cerebrospinal fluid.\n"
form['KSOURCE'] = ksource
form['COMMAND_ARGS'] = args
serviceticket = ticket
params = {'ticket': serviceticket}
headers = {'Accept': 'application/json'}
s = requests.Session()
response = s.post(serviceurl, form, headers=headers, params=params, allow_redirects=False)

# %%
def get_redirect_target(resp):
        """Receives a Response. Returns a redirect URI or ``None``"""
        # Due to the nature of how requests processes redirects this method will
        # be called at least once upon the original response and at least twice
        # on each subsequent redirect response (if any).
        # If a custom mixin is used to handle this logic, it may be advantageous
        # to cache the redirect location onto the response object as a private
        # attribute.
        if resp.is_redirect:
            location = resp.headers["location"]
            # Currently the underlying http module on py3 decode headers
            # in latin1, but empirical evidence suggests that latin1 is very
            # rarely used with non-ASCII characters in HTTP headers.
            # It is more likely to get UTF8 header rather than latin1.
            # This causes incorrect handling of UTF8 encoded location headers.
            # To solve this, we re-encode the location in latin1.
#             print(location)
            location = location.encode("latin1")
#             print(location)
#             print(to_native_string(location, "utf8"))
            return to_native_string(location, "utf8")
        return None

if response.status_code == 302:
    newurl = s.get_redirect_target(response)
    response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)

# %%
# get concepts to map
conditions_unmapped.downcase_name.to_list()[:10]
# Out:
# ['congenital adrenal hyperplasia',
#  'cancer',
#  'obesity',
#  'diabetes',
#  'obesity',
#  'macular edema, cystoid',
#  'myopia',
#  'ischemic optic neuropathy',
#  'ischemic optic neuropathy',
#  'esophoria']

# %%
conditions_unmapped
# Out:
#              nct_id                                               name  \
# 25683   NCT00000102                     Congenital Adrenal Hyperplasia
# 228818  NCT00000105                                             Cancer
# 249384  NCT00000110                                            Obesity
# 203653  NCT00000112                                           Diabetes
# 203651  NCT00000112                                            Obesity
# ...             ...                                                ...
# 472887  NCT05794061                               Psychiatric Disorder
# 472886  NCT05794061                                           Dementia
# 472885  NCT05794061                               Cognitive Impairment
# 472884  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 472883  NCT05794087                                      Air Pollution
#
#                                             downcase_name mesh_term  \
# 25683                      congenital adrenal hyperplasia       NaN
# 228818                                             cancer       NaN
# 249384                                            obesity       NaN
# 203653                                           diabetes       NaN
# 203651                                            obesity       NaN
# ...                                                   ...       ...
# 472887                               psychiatric disorder       NaN
# 472886                                           dementia       NaN
# 472885                               cognitive impairment       NaN
# 472884  nutrition deficiency (xanth deficiency) due to...       NaN
# 472883                                      air pollution       NaN
#
#        downcase_mesh_term mesh_type
# 25683                 NaN       NaN
# 228818                NaN       NaN
# 249384                NaN       NaN
# 203653                NaN       NaN
# 203651                NaN       NaN
# ...                   ...       ...
# 472887                NaN       NaN
# 472886                NaN       NaN
# 472885                NaN       NaN
# 472884                NaN       NaN
# 472883                NaN       NaN
#
# [563678 rows x 6 columns]

# %%
len(conditions_unmapped['downcase_name'].to_list())
# Out:
# 563678

# %%
len(set(conditions_unmapped['downcase_name'].to_list()))
# Out:
# 99253

# %%
conditions_unmapped_list = list(set(conditions_unmapped.downcase_name.to_list())) # get unique unmapped terms
conditions_unmapped_list = [s + "\r\n" for s in conditions_unmapped_list] # you must include newline to process each term separately!
print(len(conditions_unmapped_list))
# Out:
# 99253

# %%
def split_list_by_length(lst):
    result = []
    current_sublist = []
    current_length = 0
    for item in lst:
        item_length = len(item)
        if current_length + item_length > 9990: # max is 10,000 char allowed by MetaMap
            result.append(current_sublist)
            current_sublist = []
            current_length = 0
        current_sublist.append(item)
        current_length += item_length
    result.append(current_sublist)
    return result

# %%
chunked_conditions_unmapped = split_list_by_length(conditions_unmapped_list)
chunked_conditions_unmapped[:1]
# Out:
# [['kearns sayer\r\n',
#   'hereditary angioedema - type 1\r\n',
#   'respiratory muscles\r\n',
#   'hepatic tumor\r\n',
#   'parent-child relationship\r\n',
#   'caesarean scar pregnancy\r\n',
#   'sleep hygiene\r\n',
#   'ganglioneuroblastoma of central nervous system\r\n',
#   'g6pd\r\n',
#   'antineoplastic adverse reaction\r\n',
#   'isoflurane\r\n',
#   'ocular tumor\r\n',
#   'triple negative breast cancer, tnbc\r\n',
#   'risk of bone fracture occurrences\r\n',
#   'infants\r\n',
#   'attenuated or transient psychosis\r\n',
#   'erythema migrans\r\n',
#   'malignant pleural mesothelioma, advanced\r\n',
#   'degenerative\r\n',
#   'ataxia\r\n',
#   'non alcoholic fatty liver\r\n',
#   'myoma of uterus\r\n',
#   'macular degeneration, choroidal neovascularization\r\n',
#   'newborn, infant, disease\r\n',
#   'viral; infection, coxsackie(virus)\r\n',
#   'functional dysphonia\r\n',
#   'advanced recurrent ovarian tumors\r\n',
#   'primary focal hyperhidrosis of the hands\r\n',
#   'gallbladder adenocarcinoma, biliary type\r\n',
#   'sacral myelomeningocele\r\n',
#   'gender differences\r\n',
#   'home blood pressure monitoring\r\n',
#   'slippery pulse\r\n',
#   'neonatal phototherapy\r\n',
#   'gene transfer\r\n',
#   'thoracic endovascular repair\r\n',
#   'drug binding to dat receptors\r\n',
#   'periodontal disease and caries\r\n',
#   'pulmonary mac\r\n',
#   'c-staged hepatocellular carcinoma in bclc classification\r\n',
#   'respiratory distress syndrome, pediatric\r\n',
#   'bloodpressure\r\n',
#   'hepatocyte receptor\r\n',
#   'deep wrinkles of the forehead\r\n',
#   'clinical decision support system (cdss)\r\n',
#   'malignant ovarian endometrioid tumor\r\n',
#   'severe marrow failure\r\n',
#   'diagnoses that require stem cell transplant\r\n',
#   'emotional disorder\r\n',
#   'mannose-binding lectin complement pathway\r\n',
#   'cervical neoplasia\r\n',
#   'hormonal changes\r\n',
#   'head and neck surgeries\r\n',
#   'hemolytic-uremic syndrome, atypical\r\n',
#   'abdominal aortic aneurysms with challenging anatomy\r\n',
#   'central blood pressure\r\n',
#   'vaccine\r\n',
#   'lower grade glioma, recurrent\r\n',
#   'male sterilization\r\n',
#   'diabetes mellitus type 2 without complication\r\n',
#   'body contouring surgery\r\n',
#   'parenteral nutrition (no primary condition studied)\r\n',
#   'lung structure determination\r\n',
#   'immunologically-induced lung disease\r\n',
#   'medulloblastoma, group 4\r\n',
#   'death, sudden,cardiac\r\n',
#   'the clinical application guide of conebeam breast ct\r\n',
#   'beta rhythm\r\n',
#   'fracture of long bones\r\n',
#   'target controlled infusion (tci)\r\n',
#   'elite athletes\r\n',
#   'primary\r\n',
#   'spina bifida and anencephaly\r\n',
#   'pre-term birth\r\n',
#   'grönblad-stranberg disease (pseudoxanthoma elasticum)\r\n',
#   'hip impairments\r\n',
#   'vulval dermatoses\r\n',
#   'sex hormones\r\n',
#   'squamous-cell non-small cell lung cancer\r\n',
#   'suspected lung cancer\r\n',
#   'sleep disturbances in survivors of critical illness\r\n',
#   'age-related sarcopenia\r\n',
#   'bra strap fat (bsf)\r\n',
#   'chronic periaortitis\r\n',
#   'undetected intraoperative blood loss\r\n',
#   'human bocavirus\r\n',
#   'decayed tooth\r\n',
#   'allogeneic hematopoietic cell transplant recipients\r\n',
#   'popliteal nerve block\r\n',
#   'superinfection lung\r\n',
#   'pd\r\n',
#   'single dose\r\n',
#   'pustular psoriasis\r\n',
#   'pharmacologic action\r\n',
#   'chronic migraine headache\r\n',
#   'additional indications below for module 4 and 5\r\n',
#   'methamphetamine withdrawal\r\n',
#   'cortical organisation of vestibular integration\r\n',
#   'planned rrso\r\n',
#   'articular cartilage defects of knee\r\n',
#   'self reported ratings of hunger\r\n',
#   'rectal hyposensitivity\r\n',
#   'fetal renal anomaly\r\n',
#   'cartilage injuries in the human knee\r\n',
#   'kcnma1-channelopathy\r\n',
#   'community-dwelling older adults\r\n',
#   'parkinson disease, mitochondrial\r\n',
#   'adherence to personalized ebm anticoagulant treatment in patients at high risk for stroke\r\n',
#   'acute alcohol intoxication\r\n',
#   'rheumatoid arthritis - hand joint\r\n',
#   'pharmacogenetic study\r\n',
#   'recurrent staphylococcal infection\r\n',
#   'ass-nonresponse\r\n',
#   'hematopoietic stem cell transplantation-associated thrombotic microangiopathy\r\n',
#   'small bowel bacterial overgrowth syndrome (sbbos)\r\n',
#   'adverse outcomes\r\n',
#   'absorption; chemicals\r\n',
#   'well-being\r\n',
#   'arterial thromboembolism\r\n',
#   'breast hypoplasia\r\n',
#   'brain edema caused by drugs\r\n',
#   'innate inflammatory response\r\n',
#   'stage iii kidney cancer\r\n',
#   'unresponsive wakefulness syndrome\r\n',
#   'early childhood caries, vitamin d deficiency\r\n',
#   'vulvar cancer\r\n',
#   'morquio syndrome a\r\n',
#   'blood donors, traumatic blood loss\r\n',
#   'inflammatory myopathy\r\n',
#   'basic english speaker\r\n',
#   'norwalk gastroenteritis\r\n',
#   'thyroid hormones\r\n',
#   'short uterine cervical length\r\n',
#   'extrapyramidal symptoms\r\n',
#   'neonatal hypothermia\r\n',
#   'parotid gland tumor\r\n',
#   'taste testing\r\n',
#   'prostate cancer metastatic\r\n',
#   'upper airway sonographic evaluation\r\n',
#   'multiresistant bacterial pathogens\r\n',
#   'hemiplegic\r\n',
#   'hepatitis c virus (hcv) coinfection\r\n',
#   'central pain syndromes\r\n',
#   'familial atrial fibrillation\r\n',
#   'gastric, or gastroesophageal junction adenocarcinoma\r\n',
#   'osteosarcoma of pelvis\r\n',
#   'cataract mature\r\n',
#   'caries; initial\r\n',
#   'arthroplasty, replacement, knee\r\n',
#   'crohn disease of vulva\r\n',
#   'single photon emission computed tomography\r\n',
#   'ibs-c and ibs with mixed bowel habits\r\n',
#   'enterobacteria susceptible to carbapenem carrier\r\n',
#   'rendu osler weber\r\n',
#   'postoperative ecchymosis\r\n',
#   'choroidal neo-vascular age-onset macular degeneration\r\n',
#   'solid organ transplantation recipient\r\n',
#   'radiation-induced fibrosis in patients with head and neck cancer\r\n',
#   'asphyxiating thoracic dystrophy\r\n',
#   'dropout\r\n',
#   'diphtheria vaccine adverse reaction\r\n',
#   'progressive metastatic malignancies\r\n',
#   'oculopalatal tremor\r\n',
#   'sars-cov 2\r\n',
#   'malignant hematologic neoplasm\r\n',
#   'small cell lung cancers\r\n',
#   'post-anoxic coma\r\n',
#   'bilateral nasal polyposis\r\n',
#   'advance directives\r\n',
#   'perfusion index as an early predictor of successful supraclavicular block\r\n',
#   'diabetic foot ulcer outcome\r\n',
#   'ear, nose and throat disorder\r\n',
#   'onset and duration of a digital nerve block\r\n',
#   'adult stem cells\r\n',
#   'craniocerebral injuries\r\n',
#   'gynecologic oncological pelvic/abdominal surgery\r\n',
#   'minimally invasive fetoscopic procedures\r\n',
#   "vater's ampulla\r\n",
#   'loiasis\r\n',
#   'chloasma\r\n',
#   'glucose-galactose malabsorption\r\n',
#   'case fatality rate\r\n',
#   'allogeneic hematopoietic transplant\r\n',
#   'treatment-refractory mycobacterium avium complex-lung disease (mac-ld)\r\n',
#   'anemia, neoplasms\r\n',
#   'intracranial surgery\r\n',
#   'dietary selenium deficiency\r\n',
#   'polr3a mutatie\r\n',
#   'noncontiguous stage ii grade 3 follicular lymphoma\r\n',
#   'cohort studies\r\n',
#   'elderly cancer patients\r\n',
#   'stage ii testicular choriocarcinoma ajcc v6 and v7\r\n',
#   'hydatidiform moles\r\n',
#   'ovarian papillary serous carcinoma\r\n',
#   'body contouring\r\n',
#   'skin graft (allograft)(autograft) failure\r\n',
#   'high dosage buprenorphine\r\n',
#   'nervus intermedius neuralgia\r\n',
#   'signs and symptoms\r\n',
#   'adult acute myeloblastic leukemia without maturation (m1)\r\n',
#   'trauma nervous system\r\n',
#   'chiropractic\r\n',
#   'fetal heart rate or rhythm abnormality affecting fetus\r\n',
#   'behavioral performance\r\n',
#   'single-photon emission computed tomography (spect)\r\n',
#   'communication aids for disabled\r\n',
#   'delayed healing\r\n',
#   'ect.\r\n',
#   'infertile patients\r\n',
#   'painful intercourse\r\n',
#   'carcinoma prostate\r\n',
#   'carcinoma of the cervix\r\n',
#   'cerebral palsy, dyskinetic\r\n',
#   '1q21.1 deletion\r\n',
#   'paravaginal cystocele\r\n',
#   'acute migraine\r\n',
#   'cryptogenic chronic hepatitis\r\n',
#   'relapsed or refractory non-hodgkin lymphoma\r\n',
#   'coronary artery disease (cad) (e.g., angina, myocardial infarction, and atherosclerotic heart disease (ashd))\r\n',
#   'b-cell small lymphocytic lymphoma\r\n',
#   'photochemotherapy\r\n',
#   'fracture of tibia fibula\r\n',
#   'human papillomavirus (hpv) infection\r\n',
#   'exacerbation of chronic heart failure\r\n',
#   'esophageal surgery cancer\r\n',
#   'covid-19 thalidomide\r\n',
#   'metastatic castration sensitive prostate cancer\r\n',
#   'mesenchymal stromal cells\r\n',
#   'prevention of chronic disease\r\n',
#   'upper gastrointestinal lesions\r\n',
#   'thoracic aorta\r\n',
#   'stage iic fallopian tube cancer\r\n',
#   'pincer nail\r\n',
#   'mechanical ventilation time\r\n',
#   'acne detergicans\r\n',
#   'malignant and pre-malignant changes in the polyp\r\n',
#   'prophylaxis of influenza\r\n',
#   'biological samples\r\n',
#   'opiate substitution treatment\r\n',
#   'able bodied\r\n',
#   'aids-related immunoblastic large cell lymphoma\r\n',
#   'overall response rate\r\n',
#   'clinical stage iii hpv-mediated (p16-positive) oropharyngeal carcinoma ajcc v8\r\n',
#   'retirement\r\n',
#   'early-onset alzheimer disease\r\n',
#   'impoverished population\r\n',
#   'diabetic stable angina\r\n',
#   'patient without treatment against a.fumigatus\r\n',
#   'oral bacteria levels in the mouth\r\n',
#   'chronic pancreatitis\r\n',
#   'patient doctor trust\r\n',
#   'hormone-dependent prostate cancer\r\n',
#   'endometrioid adenocarcinoma\r\n',
#   'opioid use disorders\r\n',
#   'metastatic malignant neoplasm in the thoracic cavity\r\n',
#   'embolization therapeutic\r\n',
#   'ulcerative rectocolitis\r\n',
#   'adult-onset diabetes mellitus\r\n',
#   'congenital heart block\r\n',
#   'urologic surgical procedures\r\n',
#   'apomorphine-induced skin reactions\r\n',
#   'endobronchial growth\r\n',
#   'natural kicetics of d-dimers after surgery\r\n',
#   'infection rate after fingertip amputation\r\n',
#   'healed erosive esophagitis\r\n',
#   'dementia with lewy bodies diagnosis\r\n',
#   'sugammadex\r\n',
#   'platinum-sensitive ovarian cancer (upgrade-a)\r\n',
#   'sandplay therapy\r\n',
#   'brca1/2\r\n',
#   'diabetic peripheral vascular disease\r\n',
#   'carcinoma breast stage iv\r\n',
#   'airway device\r\n',
#   'icd and crt-d indicated patients\r\n',
#   'mild to moderate depression.\r\n',
#   'acute ischemic stroke, cerebral embolism and thrombosis\r\n',
#   'recurrent viral meningitis\r\n',
#   'pediatric hematologic malignancies\r\n',
#   'euglycemia\r\n',
#   'exercise fat oxidation\r\n',
#   'prostate cancer screening\r\n',
#   'malnourished children\r\n',
#   'pathologic stage ib cutaneous melanoma ajcc v8\r\n',
#   'fear of needles\r\n',
#   'atypical/malignant meningioma\r\n',
#   'vaping cessation\r\n',
#   'healthcare common procedure coding system\r\n',
#   'critical aortic stenosis\r\n',
#   'pancreas tumor\r\n',
#   'oropharynx metastases\r\n',
#   'acral melanoma that has been removed by surgery\r\n',
#   'bcr-abl positive chronic myelogenous leukemia\r\n',
#   'coronary artery dissection, spontaneous\r\n',
#   'bipolar affective disorder; remission in\r\n',
#   'transversalis fascia plane block\r\n',
#   'chronic rhinosinusitis with nasal polyposis\r\n',
#   'xerosis due to atopic dermatitis\r\n',
#   'osteoarthritis hand carpometacarpal joint first\r\n',
#   'postnatal growth disorder\r\n',
#   'hypertensive nephropathy\r\n',
#   'recurrent grade 2 follicular lymphoma\r\n',
#   'environmental allergy\r\n',
#   'posterior cerebral artery stroke\r\n',
#   'adenocarcinoma of the rectum\r\n',
#   'beta-lactam antibiotic toxicity (diagnosis)\r\n',
#   'discogenic pain\r\n',
#   'preventing blood leakage of bronchial cuff\r\n',
#   'violence, non-accidental\r\n',
#   'improved healing of scarred vocal folds\r\n',
#   'persistent pain after delivery\r\n',
#   '100 adults aged between 20 and 70 years old\r\n',
#   'resectable pancreatic cancers\r\n',
#   'cervical compression myelopathy\r\n',
#   'gastric motor dysfunction\r\n',
#   'age associated immune deficiency\r\n',
#   'infiltrating renal pelvis and ureter urothelial carcinoma\r\n',
#   'quality of signout\r\n',
#   'renal transplant complication primary non-function\r\n',
#   'relapse testicular cancer\r\n',
#   'patient hopsitalized in internal medicine unit\r\n',
#   'comfort and performance of intermittent catheter\r\n',
#   'bleeding wound\r\n',
#   'brittle type 1 diabetes mellitus\r\n',
#   'effects of krill oil on human health\r\n',
#   'dialysis catheter infections\r\n',
#   'breast neoplasms, triple-negative\r\n',
#   'rugby\r\n',
#   'composite restorations\r\n',
#   'sutured wounds\r\n',
#   'hip and knee replacement surgeries\r\n',
#   'extranodal nk-t-cell lymphoma\r\n']]

# %%
"""
-I = return CUIs/identifiers
-i = ignore word order
-C = relaxed model
-z = term processing
-f = give numbers to the final mappings (adds 1. to the first mapped concept, 2. to the 2nd, and so on...)
-c = give numbers to the candidates (adds 1. to the first candidate, 2. to the 2nd, and so on...)
--sldi = read each term in list separately, do not lump into large phrase
-N = MMI formatted output

https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/ListOfTerms.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/TermProcessing.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/MM_2016_Usage.pdf
"""
args = ['--sldi -i -I -C -z']
# args = ['-I --prune 5']
form = {}
form['KSOURCE'] = ksource
form['COMMAND_ARGS'] = args
headers = {'Accept': 'application/json'}

mm_conditions = {}
for chunk in chunked_conditions_unmapped:
# for chunk in chunked_conditions_unmapped:
#     print(chunk[:3])
#     chunk = chunk[:3]
    service_ticket = get_ticket(CAS_SERVERURL, apikey, serviceurl)
#     chunk = chunk[:5] # demo for testing
    form['APIText'] = chunk
    params = {'ticket': service_ticket}
    response = s.post(serviceurl, form, headers=headers, params=params, allow_redirects=False)
    if response.status_code == 302:
        newurl = s.get_redirect_target(response)
        response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)
        
#     print(response.text)
#     print(response.content)
    for line in response.text.splitlines():
#         for line.startswith('Phrase:'):
#             mm_input = line.split(":")[1].strip()
        if not any(s in line for s in ["Meta Mapping", "Processing", "/dmzfiler/"]):
#             mm_dict = {}
            if "Phrase:" in line:
                mm_input = line.split(":")[1].strip()
#                 print(mm_input)
            else:
                cuis_per_input = []
                cui_line = [s.strip() for s in line.split('   ') if s]
                if cui_line:
#                     print(cui_line)
                    cui = cui_line[1].split(":")[0].strip()
#                     print(cui)
                    name_semtype = cui_line[1].split(":")[1].strip()
                    name = name_semtype.split("[")[0].strip()
#                     print(name)
                    semtype = re.findall(r'\[([^]]+)\]', name_semtype)
                    cui_info = [cui, name, semtype]
#                     print(mm_input)
#                     print(c_info)
                    cuis_per_input.append(cui_info)
    #                 print(cuis_per_input)
                else:
                    cuis_per_input.append(None)
                mm_conditions[mm_input] = cuis_per_input
# Out:
# ['1000', 'C0398775:Hereditary angioedema - type 1 (Hereditary C1 esterase inhibitor deficiency - deficient factor) [Disease or Syndrome]']
# ['1000', 'C2717905:Hereditary angio oedema Type 1 (Hereditary Angioedema Types I and II) [Disease or Syndrome]']
# ['1000', 'C0021724:Respiratory Muscles (Structure of intercostal muscle) [Body Part, Organ, or Organ Component]']
# ['1000', 'C0035231:Respiratory Muscles [Body Part, Organ, or Organ Component]']
# ['1000', 'C0023903:Hepatic tumour (Liver neoplasms) [Neoplastic Process]']
# ['1000', 'C0030542:Parent-Child Relationship [Social Behavior]']
# ['1000', 'C1705423:Parent-Child Relationship (isa Relationship) [Idea or Concept]']
# ['1000', 'C2826537:Parent-Child Relationship (has_a Relationship) [Conceptual Entity]']
# ['1000', 'C4289806:Cesarean Scar Pregnancy [Finding]']
# ['1000', 'C4277672:Sleep Hygiene [Individual Behavior]']
# ['1000', 'C2010420:Ganglioneuroblastoma of central nervous system (Central Nervous System Ganglioneuroblastoma) [Neoplastic Process]']
# ['1000', 'C0017757:G6PD (Glucosephosphate Dehydrogenase) [Amino Acid, Peptide, or Protein,Enzyme]']
# ['1000', 'C1333652:G6PD (G6PD gene) [Gene or Genome]']
# ['1000', 'C2939465:G6PD (Deficiency of glucose-6-phosphate dehydrogenase) [Disease or Syndrome]']
# ['1000', 'C0569491:Antineoplastic adverse reaction [Pathologic Function]']
# ['1000', 'C0022180:ISOFLURANE (isoflurane) [Organic Chemical,Pharmacologic Substance]']
# ['1000', 'C0015414:Ocular Tumour (Eye Neoplasms) [Neoplastic Process]']
# ['1000', 'C3539878:TNBC - Triple-negative breast cancer (Triple Negative Breast Neoplasms) [Neoplastic Process]']
# ['760', 'C0035647:Risk [Idea or Concept]']
# ['677', 'C0016658:Fracture of Bone (Fracture) [Injury or Poisoning]']
# ['593', 'C2745955:Occurrences (Occurrence) [Temporal Concept]']
# ['760', 'C4552904:risk (Subject Risk) [Conceptual Entity]']
# ['677', 'C0016658:Fracture of Bone (Fracture) [Injury or Poisoning]']
# ['593', 'C2745955:Occurrences (Occurrence) [Temporal Concept]']
# ['1000', 'C0021270:Infants (Infant) [Age Group]']
# ['770', 'C0332161:Attenuated (Attenuated by (contextual qualifier)) [Qualitative Concept]']
# ['770', 'C0040704:Transient (Transient Population Group) [Population Group]']
# ['770', 'C0033975:PSYCHOSIS (Psychotic Disorders) [Mental or Behavioral Dysfunction]']
# ['770', 'C0332161:Attenuated (Attenuated by (contextual qualifier)) [Qualitative Concept]']
# ['770', 'C0040704:Transient (Transient Population Group) [Population Group]']
# ['770', 'C0349204:Psychosis NOS (Nonorganic psychosis) [Mental or Behavioral Dysfunction]']
# ['770', 'C0332161:Attenuated (Attenuated by (contextual qualifier)) [Qualitative Concept]']
# ['770', 'C0040704:Transient (Transient Population Group) [Population Group]']
# ['770', 'C4554629:Psychosis (Psychosis, CTCAE) [Finding]']
# ['770', 'C0332161:Attenuated (Attenuated by (contextual qualifier)) [Qualitative Concept]']
# ['770', 'C0205374:Transient (Transitory) [Temporal Concept]']
# ['770', 'C0033975:PSYCHOSIS (Psychotic Disorders) [Mental or Behavioral Dysfunction]']
# ['770', 'C0332161:Attenuated (Attenuated by (contextual qualifier)) [Qualitative Concept]']
# ['770', 'C0205374:Transient (Transitory) [Temporal Concept]']
# ['770', 'C0349204:Psychosis NOS (Nonorganic psychosis) [Mental or Behavioral Dysfunction]']
# ['770', 'C0332161:Attenuated (Attenuated by (contextual qualifier)) [Qualitative Concept]']
# ['770', 'C0205374:Transient (Transitory) [Temporal Concept]']
# ['770', 'C4554629:Psychosis (Psychosis, CTCAE) [Finding]']
# ['770', 'C0599946:Attenuated (Attenuation) [Activity]']
# ['770', 'C0040704:Transient (Transient Population Group) [Population Group]']
# ['770', 'C0033975:PSYCHOSIS (Psychotic Disorders) [Mental or Behavioral Dysfunction]']
# ['770', 'C0599946:Attenuated (Attenuation) [Activity]']
# ['770', 'C0040704:Transient (Transient Population Group) [Population Group]']
# ['770', 'C0349204:Psychosis NOS (Nonorganic psychosis) [Mental or Behavioral Dysfunction]']
# ['770', 'C0599946:Attenuated (Attenuation) [Activity]']
# ['770', 'C0040704:Transient (Transient Population Group) [Population Group]']
# ['770', 'C4554629:Psychosis (Psychosis, CTCAE) [Finding]']
# ['770', 'C0599946:Attenuated (Attenuation) [Activity]']
# ['770', 'C0205374:Transient (Transitory) [Temporal Concept]']
# ['770', 'C0033975:PSYCHOSIS (Psychotic Disorders) [Mental or Behavioral Dysfunction]']
# ['770', 'C0599946:Attenuated (Attenuation) [Activity]']
# ['770', 'C0205374:Transient (Transitory) [Temporal Concept]']
# ['770', 'C0349204:Psychosis NOS (Nonorganic psychosis) [Mental or Behavioral Dysfunction]']
# ['770', 'C0599946:Attenuated (Attenuation) [Activity]']
# ['770', 'C0205374:Transient (Transitory) [Temporal Concept]']
# ['770', 'C4554629:Psychosis (Psychosis, CTCAE) [Finding]']
# ['1000', 'C0014740:Erythema Migrans (Erythema Chronicum Migrans) [Disease or Syndrome]']
# ['1000', 'C0017677:erythema migrans (Glossitis, Benign Migratory) [Disease or Syndrome]']
# ['1000', 'C0854889:Advanced Malignant pleural mesothelioma (Advanced Pleural Malignant Mesothelioma) [Neoplastic Process]']
# ['1000', 'C0011164:Degenerative (Abnormal degeneration) [Pathologic Function]']
# ['1000', 'C1880269:Degenerative (biologic degeneration) [Functional Concept]']
# ['1000', 'C0004134:ATAXIA (Ataxia) [Sign or Symptom]']
# ['1000', 'C0007758:Ataxia (Cerebellar Ataxia) [Disease or Syndrome]']
# ['1000', 'C4554639:Ataxia (Ataxia, CTCAE 5.0) [Finding]']
# ['1000', 'C0400966:Nonalcoholic Fatty Liver (Non-alcoholic Fatty Liver Disease) [Disease or Syndrome]']
# ['858', 'C0042133:uterus myoma (Uterine Fibroids) [Neoplastic Process]']
# ['604', 'C0027686:Neovascularisation (Pathologic Neovascularization) [Pathologic Function]']
# ['868', 'C0423425:Macular Choroidal degeneration (Macular choroidal sclerosis) [Finding]']
# ['898', 'C0021290:Infant, Newborn, Diseases (Neonatal disorder) [Disease or Syndrome]']
# ['881', 'C0010246:Coxsackievirus Infection (Coxsackievirus Infections) [Disease or Syndrome]']
# ['532', 'C0042776:VIRUSES (Virus) [Virus]']
# ['881', 'C0010246:Coxsackievirus Infection (Coxsackievirus Infections) [Disease or Syndrome]']
# ['532', 'C0521026:viruses (Viral) [Functional Concept]']
# ['1000', 'C0264622:functional dysphonia (Psychogenic voice disorder) [Disease or Syndrome]']
# ['604', 'C0205179:Advanced (Advanced phase) [Qualitative Concept]']
# ['819', 'C0521158:Recurrent Tumors (Recurrent tumor) [Neoplastic Process]']
# ['770', 'C0205065:Ovarian [Body Part, Organ, or Organ Component]']
# ['604', 'C0205179:Advanced (Advanced phase) [Qualitative Concept]']
# ['604', 'C1455761:Recurrent (Episodic) [Temporal Concept]']
# ['833', 'C0919267:Ovarian Tumors (ovarian neoplasm) [Neoplastic Process]']
# ['604', 'C0205179:Advanced (Advanced phase) [Qualitative Concept]']
# ['604', 'C2945760:RECURRENT (Recurrent) [Temporal Concept]']
# ['833', 'C0919267:Ovarian Tumors (ovarian neoplasm) [Neoplastic Process]']
# ['833', 'C1456132:Primary focal hyperhidrosis [Disease or Syndrome]']
# ['586', 'C0018563:Hands (Hand) [Body Part, Organ, or Organ Component]']
# ['833', 'C1456132:Primary focal hyperhidrosis [Disease or Syndrome]']
# ['586', 'C1552914:hand (hand - unit of measure) [Quantitative Concept]']
# ['1000', 'C3273113:Gallbladder Adenocarcinoma, Biliary Type [Neoplastic Process]']
# ['1000', 'C0521556:Sacral Myelomeningocele (Congenital sacral meningocele) [Congenital Abnormality]']
# ['1000', 'C0036866:Gender Differences (Sex Characteristics) [Organism Attribute]']
# ['1000', 'C1449681:Blood Pressure Monitoring, Home [Diagnostic Procedure]']
# ['833', 'C0232117:PULSE (Pulse Rate) [Clinical Attribute]']
# ['833', 'C0391850:Pulse (Physiologic pulse) [Physiologic Function]']
# ['833', 'C1947910:Pulse (Pulse phenomenon) [Phenomenon or Process]']
# ['1000', 'C0199741:Neonatal phototherapy (Phototherapy of newborn) [Therapeutic or Preventive Procedure]']
# ['1000', 'C0017296:Gene transfer (gene therapy) [Therapeutic or Preventive Procedure]']
# ['1000', 'C1517499:Gene Transfer [Molecular Biology Research Technique]']
# ['790', 'C0524425:Endovascular (inside the blood vessel) [Body Location or Region]']
# ['790', 'C0043240:Repair, NOS (Wound Healing) [Organism Function]']
# ['790', 'C0524425:Endovascular (inside the blood vessel) [Body Location or Region]']
# ['790', 'C0374711:Repair, NOS (Surgical repair) [Therapeutic or Preventive Procedure]']
# ['790', 'C0524425:Endovascular (inside the blood vessel) [Body Location or Region]']
# ['790', 'C4319951:Repair [Functional Concept]']
# ['806', 'C0678749:drug binding [Physiologic Function]']
# ['593', 'C1439340:DAT (SLC6A3 protein, human) [Amino Acid, Peptide, or Protein,Biologically Active Substance]']
# ['593', 'C0597357:Receptors (receptor) [Amino Acid, Peptide, or Protein,Receptor]']
# ['806', 'C0678749:drug binding [Physiologic Function]']
# ['593', 'C3813713:DAT (SLC6A3 wt Allele) [Gene or Genome]']
# ['593', 'C0597357:Receptors (receptor) [Amino Acid, Peptide, or Protein,Receptor]']
# ['797', 'C0034799:Drug receptors (Receptors, Drug) [Amino Acid, Peptide, or Protein,Receptor]']
# ['760', 'C1145667:Binding (Binding action) [Activity]']
# ['593', 'C1439340:DAT (SLC6A3 protein, human) [Amino Acid, Peptide, or Protein,Biologically Active Substance]']
# ['797', 'C0034799:Drug receptors (Receptors, Drug) [Amino Acid, Peptide, or Protein,Receptor]']
# ['760', 'C1145667:Binding (Binding action) [Activity]']
# ['593', 'C3813713:DAT (SLC6A3 wt Allele) [Gene or Genome]']
# ['797', 'C0034799:Drug receptors (Receptors, Drug) [Amino Acid, Peptide, or Protein,Receptor]']
# ['760', 'C1167622:Binding (Binding (Molecular Function)) [Molecular Function]']
# ['593', 'C1439340:DAT (SLC6A3 protein, human) [Amino Acid, Peptide, or Protein,Biologically Active Substance]']
# ['797', 'C0034799:Drug receptors (Receptors, Drug) [Amino Acid, Peptide, or Protein,Receptor]']
# ['760', 'C1167622:Binding (Binding (Molecular Function)) [Molecular Function]']
# ['593', 'C3813713:DAT (SLC6A3 wt Allele) [Gene or Genome]']
# ['833', 'C0031090:PERIODONTAL DISEASE (Periodontal Diseases) [Disease or Syndrome]']
# ['604', 'C0011334:Caries (Dental caries) [Disease or Syndrome]']
# ['833', 'C0031090:PERIODONTAL DISEASE (Periodontal Diseases) [Disease or Syndrome]']
# ['604', 'C0333519:Caries (Caries (morphologic abnormality)) [Disease or Syndrome]']
# ['833', 'C1559300:Periodontal Disease (Periodontal Disease, CTCAE) [Finding]']
# ['604', 'C0011334:Caries (Dental caries) [Disease or Syndrome]']
# ['833', 'C1559300:Periodontal Disease (Periodontal Disease, CTCAE) [Finding]']
# ['604', 'C0333519:Caries (Caries (morphologic abnormality)) [Disease or Syndrome]']
# ['666', 'C0024109:pulmonary (Lung) [Body Part, Organ, or Organ Component]']
# ['833', 'C3538559:MAC (Mitochondrion-associated adherens complex location) [Cell Component]']
# ['666', 'C0024109:pulmonary (Lung) [Body Part, Organ, or Organ Component]']
# ['833', 'C4049728:MAC (MARCKS wt Allele) [Gene or Genome]']
# ['666', 'C2707265:Pulmonary (Pulmonary:-:Point in time:^Patient:-) [Clinical Attribute]']
# ['833', 'C3538559:MAC (Mitochondrion-associated adherens complex location) [Cell Component]']
# ['666', 'C2707265:Pulmonary (Pulmonary:-:Point in time:^Patient:-) [Clinical Attribute]']
# ['833', 'C4049728:MAC (MARCKS wt Allele) [Gene or Genome]']
# ['666', 'C2709248:Pulmonary (Pulmonary (qualifier value)) [Qualitative Concept]']
# ['833', 'C3538559:MAC (Mitochondrion-associated adherens complex location) [Cell Component]']
# ['666', 'C2709248:Pulmonary (Pulmonary (qualifier value)) [Qualitative Concept]']
# ['833', 'C4049728:MAC (MARCKS wt Allele) [Gene or Genome]']
# ['666', 'C4522268:Pulmonary (Pulmonary (intended site)) [Finding]']
# ['833', 'C3538559:MAC (Mitochondrion-associated adherens complex location) [Cell Component]']
# ['666', 'C4522268:Pulmonary (Pulmonary (intended site)) [Finding]']
# ['833', 'C4049728:MAC (MARCKS wt Allele) [Gene or Genome]']
# ['848', 'C3899977:BCLC Stage C Hepatocellular Carcinoma [Neoplastic Process]']
# ['581', 'C0008902:Classification [Classification]']
# ['848', 'C3899977:BCLC Stage C Hepatocellular Carcinoma [Neoplastic Process]']
# ['581', 'C0008903:classification (Taxonomic) [Functional Concept]']
# ['848', 'C3899977:BCLC Stage C Hepatocellular Carcinoma [Neoplastic Process]']
# ['581', 'C0678229:classification (Classification of information) [Occupational Activity]']
# ['1000', 'C5392184:Respiratory Distress Syndrome, Pediatric [Disease or Syndrome]']
# ['1000', 'C0005823:BLOOD PRESSURE (Blood Pressure) [Organism Function]']
# ['1000', 'C1271104:Blood Pressure (Blood pressure finding) [Finding]']
# ['1000', 'C1272641:Blood pressure (Systemic arterial pressure) [Finding]']
# ['666', 'C0227525:Hepatocyte [Cell]']
# ['833', 'C0597357:Receptor (receptor) [Amino Acid, Peptide, or Protein,Receptor]']
# ['666', 'C0669372:Hepatocyte NOS (NOS2A protein, human) [Amino Acid, Peptide, or Protein,Enzyme]']
# ['833', 'C0597357:Receptor (receptor) [Amino Acid, Peptide, or Protein,Receptor]']
# ['593', 'C0205125:DEEP (Deep (qualifier value)) [Spatial Concept]']
# ['833', 'C1997891:Wrinkle of forehead (Rhytide of forehead) [Finding]']
# ['593', 'C4318566:Deep (Deep Resection Margin) [Clinical Attribute]']
# ['833', 'C1997891:Wrinkle of forehead (Rhytide of forehead) [Finding]']
# ['1000', 'C0525070:Clinical Decision Support System (Decision Support Systems, Clinical) [Intellectual Product]']
# ['1000', 'C1518231:Malignant Ovarian Endometrioid Tumor [Neoplastic Process]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C0205082:SEVERE (Severe (severity modifier)) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4050465:Severe (Severe Extremity Pain) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4050466:Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4722466:Severe (Severe Hallucination) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C4761449:Severe (Epidermal cGVHD Score 4) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C0086590:Marrow (Vegetable marrow) [Food]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C0376152:Marrow [Body Part, Organ, or Organ Component]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0231174:Failure (Failure (biologic function)) [Functional Concept]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C0680095:failure (Personal failure) [Individual Behavior]']
# ['623', 'C5203119:Severe (Intensity and Distress 5) [Finding]']
# ['623', 'C1546708:Marrow (Marrow - Specimen Source Codes) [Intellectual Product]']
# ['790', 'C5200924:FAILURE (Failure) [Idea or Concept]']
# ['753', 'C0011900:Diagnoses (Diagnosis) [Diagnostic Procedure]']
# ['666', 'C1504389:Stem Cell Transplant (Stem cell transplant) [Therapeutic or Preventive Procedure]']
# ['1000', 'C0233459:Emotional disorder [Mental or Behavioral Dysfunction]']
# ['1000', 'C1138407:Complement Pathway, Mannose-Binding Lectin [Molecular Function]']
# ['1000', 'C0007873:cervical Neoplasia (Uterine Cervical Neoplasm) [Neoplastic Process]']
# ['1000', 'C1134488:hormonal changes (Hormonal Change) [Finding]']
# ['991', 'C1512343:Head and Neck Surgery [Health Care Activity]']
# ['1000', 'C2931788:Atypical haemolytic uraemic syndrome (Atypical Hemolytic Uremic Syndrome) [Disease or Syndrome]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C0798503:Challenge (Challenge:Type:Point in time:^Patient:Nominal) [Clinical Attribute]']
# ['586', 'C0002808:Anatomy (Science of Anatomy) [Biomedical Occupation or Discipline]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C0798503:Challenge (Challenge:Type:Point in time:^Patient:Nominal) [Clinical Attribute]']
# ['586', 'C0700276:Anatomy (Anatomic structures) [Anatomical Structure]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C0798503:Challenge (Challenge:Type:Point in time:^Patient:Nominal) [Clinical Attribute]']
# ['586', 'C1384516:anatomy (Anatomy aspects) [Qualitative Concept]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C0805586:Challenge [Health Care Activity]']
# ['586', 'C0002808:Anatomy (Science of Anatomy) [Biomedical Occupation or Discipline]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C0805586:Challenge [Health Care Activity]']
# ['586', 'C0700276:Anatomy (Anatomic structures) [Anatomical Structure]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C0805586:Challenge [Health Care Activity]']
# ['586', 'C1384516:anatomy (Anatomy aspects) [Qualitative Concept]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C3274764:Challenge (Proficiency Testing Challenge) [Conceptual Entity]']
# ['586', 'C0002808:Anatomy (Science of Anatomy) [Biomedical Occupation or Discipline]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C3274764:Challenge (Proficiency Testing Challenge) [Conceptual Entity]']
# ['586', 'C0700276:Anatomy (Anatomic structures) [Anatomical Structure]']
# ['833', 'C0162871:Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) [Disease or Syndrome]']
# ['553', 'C3274764:Challenge (Proficiency Testing Challenge) [Conceptual Entity]']
# ['586', 'C1384516:anatomy (Anatomy aspects) [Qualitative Concept]']
# ['623', 'C0205099:CENTRAL (Central) [Spatial Concept]']
# ['882', 'C0005823:BLOOD PRESSURE (Blood Pressure) [Organism Function]']
# ['623', 'C0205099:CENTRAL (Central) [Spatial Concept]']
# ['882', 'C1271104:Blood Pressure (Blood pressure finding) [Finding]']
# ['623', 'C0205099:CENTRAL (Central) [Spatial Concept]']
# ['882', 'C1272641:Blood pressure (Systemic arterial pressure) [Finding]']
# ['623', 'C1879652:Central - (Central Minus) [Laboratory Procedure]']
# ['882', 'C0005823:BLOOD PRESSURE (Blood Pressure) [Organism Function]']
# ['623', 'C1879652:Central - (Central Minus) [Laboratory Procedure]']
# ['882', 'C1271104:Blood Pressure (Blood pressure finding) [Finding]']
# ['623', 'C1879652:Central - (Central Minus) [Laboratory Procedure]']
# ['882', 'C1272641:Blood pressure (Systemic arterial pressure) [Finding]']
# ['1000', 'C0042210:Vaccine (Vaccines) [Amino Acid, Peptide, or Protein,Immunologic Factor,Pharmacologic Substance]']
# ['1000', 'C5399710:Vaccine (Vaccine [APC]) [Pharmacologic Substance]']
# ['988', 'C4688341:Recurrent Low-Grade Glioma (Recurrent WHO Grade II Glioma) [Neoplastic Process]']
# ['1000', 'C0024559:Male sterilisation (Male sterilization) [Therapeutic or Preventive Procedure]']
# ['925', 'C0494290:Type 2 diabetes mellitus without complication [Disease or Syndrome]']
# ['1000', 'C2224569:Surgery, Body Contouring (Body Contouring) [Therapeutic or Preventive Procedure]']
# ['790', 'C0030547:PARENTERAL NUTRITION (Parenteral Nutrition) [Therapeutic or Preventive Procedure]']
# ['623 N C0277554:primary condition (primary disorders) [Disease or Syndrome]']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [35], in <cell line: 23>()
#      49                 if cui_line:
#      50                     print(cui_line)
# ---> 51                     cui = cui_line[1].split(":")[0].strip()
#      52 #                     print(cui)
#      53                     name_semtype = cui_line[1].split(":")[1].strip()
#
# IndexError: list index out of range

# %%
"""
-I = return CUIs/identifiers
-i = ignore word order
-C = relaxed model
-z = term processing
-f = give numbers to the final mappings (adds 1. to the first mapped concept, 2. to the 2nd, and so on...)
-c = give numbers to the candidates (adds 1. to the first candidate, 2. to the 2nd, and so on...)
--sldi = read each term in list separately, do not lump into large phrase
-N = MMI formatted output

https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/ListOfTerms.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/TermProcessing.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/MM_2016_Usage.pdf
"""
args = ['--sldi -i -I -C -z']
# args = ['-I --prune 5']
form = {}
form['KSOURCE'] = ksource
form['COMMAND_ARGS'] = args
headers = {'Accept': 'application/json'}

mm_conditions = {}
# for chunk in chunked_conditions_unmapped:
for chunk in chunked_conditions_unmapped[:3]:
#     print(chunk[:3]) # demo for testing
    chunk = chunk[:3] # demo for testing
    service_ticket = get_ticket(CAS_SERVERURL, apikey, serviceurl)
    form['APIText'] = chunk
    params = {'ticket': service_ticket}
    response = s.post(serviceurl, form, headers=headers, params=params, allow_redirects=False)
    if response.status_code == 302:
        newurl = s.get_redirect_target(response)
        response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)
        
#     print(response.text)
#     print(response.content)
    for line in response.text.splitlines():
#         for line.startswith('Phrase:'):
#             mm_input = line.split(":")[1].strip()
        if not any(s in line for s in ["Meta Mapping", "Processing", "/dmzfiler/"]):
#             mm_dict = {}
            if "Phrase:" in line:
                mm_input = line.split(":")[1].strip()
                print(mm_input)
            else:
                print(line)
# Out:
# kearns sayer
#
# hereditary angioedema - type 1
#   1000   C0398775:Hereditary angioedema - type 1 (Hereditary C1 esterase inhibitor deficiency - deficient factor) [Disease or Syndrome]
#   1000   C2717905:Hereditary angio oedema Type 1 (Hereditary Angioedema Types I and II) [Disease or Syndrome]
#
# respiratory muscles
#   1000   C0021724:Respiratory Muscles (Structure of intercostal muscle) [Body Part, Organ, or Organ Component]
#   1000   C0035231:Respiratory Muscles [Body Part, Organ, or Organ Component]
#
# full thickness supraspinatus tendon tear
#    640   C0439809:Full thickness [Quantitative Concept]
#    797   C0439059:Supraspinatus tear [Injury or Poisoning]
#    593   C0039508:TENDON (Tendon structure) [Body Part, Organ, or Organ Component]
#    640   C0439809:Full thickness [Quantitative Concept]
#    640   C0224868:Supraspinatus tendon (Tendon of supraspinatus muscle) [Body Part, Organ, or Organ Component]
#    760   C0039409:TEAR (Tears body substance) [Body Substance]
#    640   C0439809:Full thickness [Quantitative Concept]
#    640   C0224868:Supraspinatus tendon (Tendon of supraspinatus muscle) [Body Part, Organ, or Organ Component]
#    760   C0043246:Tear (Laceration) [Injury or Poisoning]
#    640   C0439809:Full thickness [Quantitative Concept]
#    640   C0224868:Supraspinatus tendon (Tendon of supraspinatus muscle) [Body Part, Organ, or Organ Component]
#    760   C1704633:TEAR (Tear Shape) [Spatial Concept]
#    640   C0439809:Full thickness [Quantitative Concept]
#    640   C0224868:Supraspinatus tendon (Tendon of supraspinatus muscle) [Body Part, Organ, or Organ Component]
#    760   C3203359:tear (Rupture) [Injury or Poisoning]
#    640   C0439809:Full thickness [Quantitative Concept]
#    593   C0584869:Supraspinatus (Supraspinatus muscle structure) [Body Part, Organ, or Organ Component]
#    806   C0850773:tendon tear (Tendon tears) [Injury or Poisoning]
#
# post endodontic pain
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C0030193:PAIN (Pain) [Sign or Symptom]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C0518090:Pain (Frequency of Pain Question) [Intellectual Product]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C1962977:Pain NOS (Pain NOS, CTCAE) [Finding]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C2984058:Pain (Have Pain) [Intellectual Product]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085210:Pain (Usual Severity Pain) [Intellectual Product]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085211:Pain (Pain Distress Question) [Intellectual Product]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085212:Pain (How Much Distress Pain) [Intellectual Product]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4553004:Pain (Pain, CTCAE) [Finding]
#    623   C0687676:Post [Temporal Concept]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4554132:Pain (Feel Pain) [Intellectual Product]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C0030193:PAIN (Pain) [Sign or Symptom]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C0518090:Pain (Frequency of Pain Question) [Intellectual Product]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C1962977:Pain NOS (Pain NOS, CTCAE) [Finding]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C2984058:Pain (Have Pain) [Intellectual Product]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085210:Pain (Usual Severity Pain) [Intellectual Product]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085211:Pain (Pain Distress Question) [Intellectual Product]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085212:Pain (How Much Distress Pain) [Intellectual Product]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4553004:Pain (Pain, CTCAE) [Finding]
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4554132:Pain (Feel Pain) [Intellectual Product]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C0030193:PAIN (Pain) [Sign or Symptom]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C0518090:Pain (Frequency of Pain Question) [Intellectual Product]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C1962977:Pain NOS (Pain NOS, CTCAE) [Finding]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C2984058:Pain (Have Pain) [Intellectual Product]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085210:Pain (Usual Severity Pain) [Intellectual Product]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085211:Pain (Pain Distress Question) [Intellectual Product]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4085212:Pain (How Much Distress Pain) [Intellectual Product]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4553004:Pain (Pain, CTCAE) [Finding]
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    623   C0332274:Endodontic [Functional Concept]
#    790   C4554132:Pain (Feel Pain) [Intellectual Product]
#
# community-acquired mrsa infections
#    881   C0206171:Acquired Infections, Community (Community-Acquired Infections) [Disease or Syndrome]
#    604   C1265292:MRSA (Methicillin-Resistant Staphylococcus aureus) [Bacterium]
#    881   C0206171:Acquired Infections, Community (Community-Acquired Infections) [Disease or Syndrome]
#    604   C1550281:Mrsa: [Body Part, Organ, or Organ Component]
#    881   C0206171:Acquired Infections, Community (Community-Acquired Infections) [Disease or Syndrome]
#    604   C4521538:MRSA (Methicillin-resistant Staphylococcus aureus Measurement) [Laboratory or Test Result]
#
# lens; anomaly
#    833   C0023317:LENS (Lens, Crystalline) [Body Part, Organ, or Organ Component]
#    666   C0332447:Anomaly (Morphologically abnormal structure (morphologic abnormality)) [Anatomical Abnormality]
#    833   C0023317:LENS (Lens, Crystalline) [Body Part, Organ, or Organ Component]
#    666   C1704258:ANOMALY (Abnormality) [Finding]
#    833   C0023318:Lens (Lens (device)) [Manufactured Object]
#    666   C0332447:Anomaly (Morphologically abnormal structure (morphologic abnormality)) [Anatomical Abnormality]
#    833   C0023318:Lens (Lens (device)) [Manufactured Object]
#    666   C1704258:ANOMALY (Abnormality) [Finding]
#    833   C0996842:Lens (Genus Lens) [Plant]
#    666   C0332447:Anomaly (Morphologically abnormal structure (morphologic abnormality)) [Anatomical Abnormality]
#    833   C0996842:Lens (Genus Lens) [Plant]
#    666   C1704258:ANOMALY (Abnormality) [Finding]
#
# acute circulatory failure during one-lung ventilation surgery
#    800   C0036974:Acute circulatory failure (Shock) [Pathologic Function]
#    633   C0559312:One lung ventilation (One-Lung Ventilation) [Laboratory Procedure]
#    578   C0038894:Surgery (Surgery specialty) [Biomedical Occupation or Discipline]
#    800   C0036974:Acute circulatory failure (Shock) [Pathologic Function]
#    633   C0559312:One lung ventilation (One-Lung Ventilation) [Laboratory Procedure]
#    578   C0038895:surgery (Surgical aspects) [Functional Concept]
#    800   C0036974:Acute circulatory failure (Shock) [Pathologic Function]
#    633   C0559312:One lung ventilation (One-Lung Ventilation) [Laboratory Procedure]
#    578   C0543467:Surgery (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
#    800   C0036974:Acute circulatory failure (Shock) [Pathologic Function]
#    633   C0559312:One lung ventilation (One-Lung Ventilation) [Laboratory Procedure]
#    578   C1274039:Surgery (General surgery specialty) [Biomedical Occupation or Discipline]
#
# degenerative joint disease of the ankle
#    913   C0409931:Degenerative joint disease of ankle (Osteoarthritis of ankle) [Disease or Syndrome]

# %%
test = '623 N C0277554:primary condition (primary disorders) [Disease or Syndrome]'
test[].split(":")[0].strip()
# Out:
# '623 N C0277554'

# %%
"""
-I = return CUIs/identifiers
-i = ignore word order
-C = relaxed model
-z = term processing
-f = give numbers to the final mappings (adds 1. to the first mapped concept, 2. to the 2nd, and so on...)
-c = give numbers to the candidates (adds 1. to the first candidate, 2. to the 2nd, and so on...)
--sldi = read each term in list separately, do not lump into large phrase
-N = MMI formatted output

https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/ListOfTerms.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/TermProcessing.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/MM_2016_Usage.pdf
List of MetaMap semantic types: https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/SemanticTypes_2018AB.txt
"""

cwd_absolute_path = os.path.dirname(os.getcwd())
outputs_folder = "outputs/version_2"
outputs_path = os.path.join(absolute_path, outputs_folder)

# args = ['--sldi -i -I -C -z -J acab,anab,bhvr,cgab,clna,dsyn,fndg,inpo,mobd,neop,patf,sosy'] # see https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/SemanticTypes_2018AB.txt for semantic types ("acab,anab,etc.")
args = ['--sldi -i -I -C -z'] # see https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/SemanticTypes_2018AB.txt for semantic types ("acab,anab,etc.")
form = {}
form['KSOURCE'] = ksource
form['COMMAND_ARGS'] = args
headers = {'Accept': 'application/json'}

mm_conditions = {}
cui_pattern = r"C\d+(?=:)"
name_pattern = r"(?<=:)[^[]+"
semtype_pattern = r"\[(.*?)\]"

# with open('../outputs/version_2/metamapped_conditions_.txt') as output:
# with open(os.path.join(outputs_path, "metamapped_conditions.txt"), 'w') as output:

for chunk in chunked_conditions_unmapped[:3]: # demo for testing
    chunk = chunk[:20] # demo for testing
#     for chunk in chunked_conditions_unmapped:
    service_ticket = get_ticket(CAS_SERVERURL, apikey, serviceurl)
    form['APIText'] = chunk
    params = {'ticket': service_ticket}
    response = s.post(serviceurl, form, headers=headers, params=params, allow_redirects=False)
    if response.status_code == 302:
        newurl = s.get_redirect_target(response)
        response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)

    for line in response.text.splitlines():
#         output.write(line)
        if not any(s in line for s in ["Meta Mapping", "Processing", "/dmzfiler/"]):
#             mm_dict = {}
            if "Phrase:" in line:
                cuis_per_input = []
                mm_input = line.split(":")[1].strip()
                print(mm_input)
            else:
                cui_match = re.findall(cui_pattern, line)
                if cui_match:
                    name_match = re.findall(name_pattern, line)
                    semtype_match = re.findall(semtype_pattern, line)
                    cui_info = [cui_match[0].strip(), name_match[0].strip(), semtype_match[0].strip()]
                    cuis_per_input.append(cui_info)    

                mm_conditions[mm_input] = cuis_per_input



                
                
                
                
                
                
                
                
                
                
#                 cui_line = [s.strip() for s in line.split('   ') if s]
#                 if cui_line:
# #                     print(cui_line)
#                     cui = cui_line[1].split(":")[0].strip()
# #                     print(cui)
#                     name_semtype = cui_line[1].split(":")[1].strip()
#                     name = name_semtype.split("[")[0].strip()
# #                     print(name)
#                     semtype = re.findall(r'\[([^]]+)\]', name_semtype)
#                     cui_info = [cui, name, semtype]
# #                     print(mm_input)
# #                     print(c_info)
#                     cuis_per_input.append(cui_info)
#     #                 print(cuis_per_input)
#                 else:
#                     cuis_per_input.append(None)
#                 mm_conditions[mm_input] = cuis_per_input
        
        
mm_conditions
# Out:
# kearns sayer
# hereditary angioedema - type 1
# respiratory muscles
# hepatic tumor
# parent-child relationship
# caesarean scar pregnancy
# sleep hygiene
# ganglioneuroblastoma of central nervous system
# g6pd
# antineoplastic adverse reaction
# isoflurane
# ocular tumor
# triple negative breast cancer, tnbc
# risk of bone fracture occurrences
# infants
# attenuated or transient psychosis
# erythema migrans
# malignant pleural mesothelioma, advanced
# degenerative
# ataxia
# full thickness supraspinatus tendon tear
# post endodontic pain
# community-acquired mrsa infections
# low blood pressure
# transmission
# urinary infection
# mini-stroke
# flus
# infective pneumonia
# rhinosinusitis acute
# ovarian reserve
# femoral neuropathy in haemophilic patients
# anaplastic lymphoma kinase positive large b-cell lymphoma
# hyperhidrosis palmaris et plantaris
# complex regional pain syndrome
# antibodies; anti-d
# metastatic non-small cell lung cancer
# pure autonomic failure
# congenital torticollis
# disruption or dehiscence of closure of skull or craniotomy
# lens; anomaly
# acute circulatory failure during one-lung ventilation surgery
# degenerative joint disease of the ankle
# breastfeeding
# transcranial magnetic stimulation repetitive
# post-covid me/cfs
# atrium; fibrillation
# drug-related problems
# urine specimen collection
# rabies pre-exposure prophylaxis
# icd/crt-d indication
# weight loss programs
# family child care homes
# percutaneous tracheostomy
# worries
# this study was focused on selective spinal anesthesia for lower extremity surgery in order to achieve early mobilization and to shorten hospital stay
# autologous transplantation
# pcp
# platelet-rich plasma (prp)
# bone status
# {'bone status': [['C0262950',
#    'BONE (Skeletal bone)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0449438', 'Status', 'Qualitative Concept']],
#  'kearns sayer': [],
#  'hereditary angioedema - type 1': [['C0398775',
#    'Hereditary angioedema - type 1 (Hereditary C1 esterase inhibitor deficiency - deficient factor)',
#    'Disease or Syndrome'],
#   ['C2717905',
#    'Hereditary angio oedema Type 1 (Hereditary Angioedema Types I and II)',
#    'Disease or Syndrome']],
#  'respiratory muscles': [['C0021724',
#    'Respiratory Muscles (Structure of intercostal muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0035231', 'Respiratory Muscles', 'Body Part, Organ, or Organ Component']],
#  'hepatic tumor': [['C0023903',
#    'Hepatic tumour (Liver neoplasms)',
#    'Neoplastic Process']],
#  'parent-child relationship': [['C0030542',
#    'Parent-Child Relationship',
#    'Social Behavior'],
#   ['C1705423',
#    'Parent-Child Relationship (isa Relationship)',
#    'Idea or Concept'],
#   ['C2826537',
#    'Parent-Child Relationship (has_a Relationship)',
#    'Conceptual Entity']],
#  'caesarean scar pregnancy': [['C4289806',
#    'Cesarean Scar Pregnancy',
#    'Finding']],
#  'sleep hygiene': [['C4277672', 'Sleep Hygiene', 'Individual Behavior']],
#  'ganglioneuroblastoma of central nervous system': [['C2010420',
#    'Ganglioneuroblastoma of central nervous system (Central Nervous System Ganglioneuroblastoma)',
#    'Neoplastic Process']],
#  'g6pd': [['C0017757',
#    'G6PD (Glucosephosphate Dehydrogenase)',
#    'Amino Acid, Peptide, or Protein,Enzyme'],
#   ['C1333652', 'G6PD (G6PD gene)', 'Gene or Genome'],
#   ['C2939465',
#    'G6PD (Deficiency of glucose-6-phosphate dehydrogenase)',
#    'Disease or Syndrome']],
#  'antineoplastic adverse reaction': [['C0569491',
#    'Antineoplastic adverse reaction',
#    'Pathologic Function']],
#  'isoflurane': [['C0022180',
#    'ISOFLURANE (isoflurane)',
#    'Organic Chemical,Pharmacologic Substance']],
#  'ocular tumor': [['C0015414',
#    'Ocular Tumour (Eye Neoplasms)',
#    'Neoplastic Process']],
#  'triple negative breast cancer, tnbc': [['C3539878',
#    'TNBC - Triple-negative breast cancer (Triple Negative Breast Neoplasms)',
#    'Neoplastic Process']],
#  'risk of bone fracture occurrences': [['C0035647', 'Risk', 'Idea or Concept'],
#   ['C0016658', 'Fracture of Bone (Fracture)', 'Injury or Poisoning'],
#   ['C2745955', 'Occurrences (Occurrence)', 'Temporal Concept'],
#   ['C4552904', 'risk (Subject Risk)', 'Conceptual Entity'],
#   ['C0016658', 'Fracture of Bone (Fracture)', 'Injury or Poisoning'],
#   ['C2745955', 'Occurrences (Occurrence)', 'Temporal Concept']],
#  'infants': [['C0021270', 'Infants (Infant)', 'Age Group']],
#  'attenuated or transient psychosis': [['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding']],
#  'erythema migrans': [['C0014740',
#    'Erythema Migrans (Erythema Chronicum Migrans)',
#    'Disease or Syndrome'],
#   ['C0017677',
#    'erythema migrans (Glossitis, Benign Migratory)',
#    'Disease or Syndrome']],
#  'malignant pleural mesothelioma, advanced': [['C0854889',
#    'Advanced Malignant pleural mesothelioma (Advanced Pleural Malignant Mesothelioma)',
#    'Neoplastic Process']],
#  'degenerative': [['C0011164',
#    'Degenerative (Abnormal degeneration)',
#    'Pathologic Function'],
#   ['C1880269', 'Degenerative (biologic degeneration)', 'Functional Concept']],
#  'ataxia': [['C0004134', 'ATAXIA (Ataxia)', 'Sign or Symptom'],
#   ['C0007758', 'Ataxia (Cerebellar Ataxia)', 'Disease or Syndrome'],
#   ['C4554639', 'Ataxia (Ataxia, CTCAE 5.0)', 'Finding']],
#  'full thickness supraspinatus tendon tear': [['C0439809',
#    'Full thickness',
#    'Quantitative Concept'],
#   ['C0439059', 'Supraspinatus tear', 'Injury or Poisoning'],
#   ['C0039508',
#    'TENDON (Tendon structure)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0039409', 'TEAR (Tears body substance)', 'Body Substance'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0043246', 'Tear (Laceration)', 'Injury or Poisoning'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C1704633', 'TEAR (Tear Shape)', 'Spatial Concept'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C3203359', 'tear (Rupture)', 'Injury or Poisoning'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0584869',
#    'Supraspinatus (Supraspinatus muscle structure)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0850773', 'tendon tear (Tendon tears)', 'Injury or Poisoning']],
#  'post endodontic pain': [['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0030193', 'PAIN (Pain)', 'Sign or Symptom'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0518090', 'Pain (Frequency of Pain Question)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C1962977', 'Pain NOS (Pain NOS, CTCAE)', 'Finding'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C2984058', 'Pain (Have Pain)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085210', 'Pain (Usual Severity Pain)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085211', 'Pain (Pain Distress Question)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085212', 'Pain (How Much Distress Pain)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4553004', 'Pain (Pain, CTCAE)', 'Finding'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4554132', 'Pain (Feel Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0030193', 'PAIN (Pain)', 'Sign or Symptom'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0518090', 'Pain (Frequency of Pain Question)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C1962977', 'Pain NOS (Pain NOS, CTCAE)', 'Finding'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C2984058', 'Pain (Have Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085210', 'Pain (Usual Severity Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085211', 'Pain (Pain Distress Question)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085212', 'Pain (How Much Distress Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4553004', 'Pain (Pain, CTCAE)', 'Finding'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4554132', 'Pain (Feel Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0030193', 'PAIN (Pain)', 'Sign or Symptom'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0518090', 'Pain (Frequency of Pain Question)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C1962977', 'Pain NOS (Pain NOS, CTCAE)', 'Finding'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C2984058', 'Pain (Have Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085210', 'Pain (Usual Severity Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085211', 'Pain (Pain Distress Question)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085212', 'Pain (How Much Distress Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4553004', 'Pain (Pain, CTCAE)', 'Finding'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4554132', 'Pain (Feel Pain)', 'Intellectual Product']],
#  'community-acquired mrsa infections': [['C0206171',
#    'Acquired Infections, Community (Community-Acquired Infections)',
#    'Disease or Syndrome'],
#   ['C1265292',
#    'MRSA (Methicillin-Resistant Staphylococcus aureus)',
#    'Bacterium'],
#   ['C0206171',
#    'Acquired Infections, Community (Community-Acquired Infections)',
#    'Disease or Syndrome'],
#   ['C1550281', 'Mrsa:', 'Body Part, Organ, or Organ Component'],
#   ['C0206171',
#    'Acquired Infections, Community (Community-Acquired Infections)',
#    'Disease or Syndrome'],
#   ['C4521538',
#    'MRSA (Methicillin-resistant Staphylococcus aureus Measurement)',
#    'Laboratory or Test Result']],
#  'low blood pressure': [['C0020649',
#    'Low Blood Pressure (Hypotension)',
#    'Finding']],
#  'transmission': [['C0040722',
#    'transmission (disease transmission qualifier)',
#    'Idea or Concept'],
#   ['C0242781', 'Transmission (disease transmission)', 'Pathologic Function'],
#   ['C1521797',
#    'Transmission (transmission process)',
#    'Natural Phenomenon or Process']],
#  'urinary infection': [['C0042029',
#    'Urinary infection NOS (Urinary tract infection)',
#    'Disease or Syndrome']],
#  'mini-stroke': [['C0007787',
#    'Mini stroke (Transient Ischemic Attack)',
#    'Disease or Syndrome'],
#   ['C0917805',
#    'Mini-Stroke (Transient Cerebral Ischemia)',
#    'Disease or Syndrome']],
#  'flus': [['C0021400', 'flus (Influenza)', 'Disease or Syndrome']],
#  'infective pneumonia': [['C0729704',
#    'Infective pneumonia',
#    'Disease or Syndrome']],
#  'rhinosinusitis acute': [['C2317131',
#    'Acute rhinosinusitis',
#    'Disease or Syndrome']],
#  'ovarian reserve': [['C3850153',
#    'Ovarian Reserve',
#    'Organ or Tissue Function']],
#  'femoral neuropathy in haemophilic patients': [['C0751931',
#    'Femoral Neuropathy',
#    'Disease or Syndrome'],
#   ['C0030705', 'Patients', 'Patient or Disabled Group']],
#  'anaplastic lymphoma kinase positive large b-cell lymphoma': [['C1333294',
#    'Anaplastic lymphoma kinase positive large B-cell lymphoma (ALK positive large B-cell lymphoma)',
#    'Neoplastic Process']],
#  'hyperhidrosis palmaris et plantaris': [['C1274743',
#    'HYPERHIDROSIS PALMARIS ET PLANTARIS (Hyperhidrosis Palmaris Et Plantaris)',
#    'Disease or Syndrome']],
#  'complex regional pain syndrome': [['C0458219',
#    'Complex Regional Pain Syndrome (Complex Regional Pain Syndromes)',
#    'Disease or Syndrome']],
#  'antibodies; anti-d': [['C0073188',
#    'Anti D Antibody (Rho(D) immune globulin)',
#    'Amino Acid, Peptide, or Protein,Immunologic Factor,Pharmacologic Substance'],
#   ['C0140430',
#    'anti-d antibody (Blood group antibody D)',
#    'Amino Acid, Peptide, or Protein,Immunologic Factor']],
#  'metastatic non-small cell lung cancer': [['C0278987',
#    'nonsmall cell lung cancer, metastatic (Metastatic non-small cell lung cancer)',
#    'Neoplastic Process']],
#  'pure autonomic failure': [['C0393911',
#    'AUTONOMIC FAILURE, PURE (Pure Autonomic Failure)',
#    'Disease or Syndrome']],
#  'congenital torticollis': [['C0079352',
#    'Congenital torticollis',
#    'Congenital Abnormality']],
#  'disruption or dehiscence of closure of skull or craniotomy': [['C2349777',
#    'Disruption or dehiscence of closure of skull or craniotomy',
#    'Injury or Poisoning']],
#  'lens; anomaly': [['C0023317',
#    'LENS (Lens, Crystalline)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0332447',
#    'Anomaly (Morphologically abnormal structure (morphologic abnormality))',
#    'Anatomical Abnormality'],
#   ['C0023317',
#    'LENS (Lens, Crystalline)',
#    'Body Part, Organ, or Organ Component'],
#   ['C1704258', 'ANOMALY (Abnormality)', 'Finding'],
#   ['C0023318', 'Lens (Lens (device))', 'Manufactured Object'],
#   ['C0332447',
#    'Anomaly (Morphologically abnormal structure (morphologic abnormality))',
#    'Anatomical Abnormality'],
#   ['C0023318', 'Lens (Lens (device))', 'Manufactured Object'],
#   ['C1704258', 'ANOMALY (Abnormality)', 'Finding'],
#   ['C0996842', 'Lens (Genus Lens)', 'Plant'],
#   ['C0332447',
#    'Anomaly (Morphologically abnormal structure (morphologic abnormality))',
#    'Anatomical Abnormality'],
#   ['C0996842', 'Lens (Genus Lens)', 'Plant'],
#   ['C1704258', 'ANOMALY (Abnormality)', 'Finding']],
#  'acute circulatory failure during one-lung ventilation surgery': [['C0036974',
#    'Acute circulatory failure (Shock)',
#    'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C0038894',
#    'Surgery (Surgery specialty)',
#    'Biomedical Occupation or Discipline'],
#   ['C0036974', 'Acute circulatory failure (Shock)', 'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C0038895', 'surgery (Surgical aspects)', 'Functional Concept'],
#   ['C0036974', 'Acute circulatory failure (Shock)', 'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C0543467',
#    'Surgery (Operative Surgical Procedures)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0036974', 'Acute circulatory failure (Shock)', 'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C1274039',
#    'Surgery (General surgery specialty)',
#    'Biomedical Occupation or Discipline']],
#  'degenerative joint disease of the ankle': [['C0409931',
#    'Degenerative joint disease of ankle (Osteoarthritis of ankle)',
#    'Disease or Syndrome']],
#  'breastfeeding': [['C0006147',
#    'BREASTFEEDING (Breast Feeding)',
#    'Organism Function']],
#  'transcranial magnetic stimulation repetitive': [['C0872259',
#    'Repetitive Transcranial Magnetic Stimulation (Transcranial Magnetic Stimulation, Repetitive)',
#    'Therapeutic or Preventive Procedure']],
#  'post-covid me/cfs': [['C0687676', 'Post', 'Temporal Concept'],
#   ['C0015674', 'ME/CFS (Chronic Fatigue Syndrome)', 'Disease or Syndrome'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0015674', 'ME/CFS (Chronic Fatigue Syndrome)', 'Disease or Syndrome'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0015674', 'ME/CFS (Chronic Fatigue Syndrome)', 'Disease or Syndrome']],
#  'atrium; fibrillation': [['C0004238',
#    'ATRIAL FIBRILLATION (Atrial Fibrillation)',
#    'Disease or Syndrome'],
#   ['C0344434',
#    'Atrial Fibrillation (Atrial Fibrillation by ECG Finding)',
#    'Laboratory or Test Result'],
#   ['C1963067', 'Atrial Fibrillation (Atrial Fibrillation, CTCAE)', 'Finding']],
#  'drug-related problems': [['C0740721',
#    'drug problems (Drug problem)',
#    'Finding'],
#   ['C0439849', 'Related (Relationships)', 'Qualitative Concept'],
#   ['C0740721', 'drug problems (Drug problem)', 'Finding'],
#   ['C0445223', 'Related (Related personal status)', 'Finding']],
#  'urine specimen collection': [['C0200354',
#    'Specimen collection, urine (Urine Specimen Collection)',
#    'Laboratory Procedure']],
#  'rabies pre-exposure prophylaxis': [['C0034494',
#    'RABIES (Rabies (disorder))',
#    'Disease or Syndrome'],
#   ['C3850098',
#    'Pre-Exposure Prophylaxis',
#    'Therapeutic or Preventive Procedure'],
#   ['C0034496',
#    'rabies, NOS (Rabies Vaccines)',
#    'Immunologic Factor,Organic Chemical,Pharmacologic Substance'],
#   ['C3850098',
#    'Pre-Exposure Prophylaxis',
#    'Therapeutic or Preventive Procedure']],
#  'icd/crt-d indication': [['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0436307',
#    'CRT (Chemoradiotherapy)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0392360',
#    'indication (Indication of (contextual qualifier))',
#    'Idea or Concept'],
#   ['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0436307',
#    'CRT (Chemoradiotherapy)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3146298', 'Indication', 'Idea or Concept'],
#   ['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C4724071', 'CRT (SLC6A8 wt Allele)', 'Gene or Genome'],
#   ['C0392360',
#    'indication (Indication of (contextual qualifier))',
#    'Idea or Concept'],
#   ['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C4724071', 'CRT (SLC6A8 wt Allele)', 'Gene or Genome'],
#   ['C3146298', 'Indication', 'Idea or Concept']],
#  'weight loss programs': [['C3179079',
#    'Weight Loss Programs (Weight Reduction Programs)',
#    'Health Care Activity']],
#  'family child care homes': [['C0015576', 'Family', 'Family Group'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity']],
#  'percutaneous tracheostomy': [['C0584877',
#    'Percutaneous tracheostomy',
#    'Therapeutic or Preventive Procedure']],
#  'worries': [['C0233481', 'Worries (Worried)', 'Finding']],
#  'this study was focused on selective spinal anesthesia for lower extremity surgery in order to achieve early mobilization and to shorten hospital stay': [['C1080058',
#    'This (This (eukaryote))',
#    'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
# ...
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ...],
#  'autologous transplantation': [['C0040736',
#    'Autologous Transplantation (Transplantation, Autologous)',
#    'Therapeutic or Preventive Procedure']],
#  'pcp': [['C0431128',
#    'PCP (Papillary craniopharyngioma)',
#    'Neoplastic Process'],
#   ['C1535939', 'PCP (Pneumocystis jiroveci pneumonia)', 'Disease or Syndrome'],
#   ['C3896095',
#    'PCP (peptidyl carrier protein activity)',
#    'Molecular Function']],
#  'platelet-rich plasma (prp)': [['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C0032027', 'PRP (Pityriasis Rubra Pilaris)', 'Disease or Syndrome'],
#   ['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C1412228', 'PRP (ADCYAP1 gene)', 'Gene or Genome'],
#   ['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C1704926', 'PRP (ABCB6 wt Allele)', 'Gene or Genome'],
#   ['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C3889430', 'PRP (CARD14 wt Allele)', 'Gene or Genome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C0032027', 'PRP (Pityriasis Rubra Pilaris)', 'Disease or Syndrome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C1412228', 'PRP (ADCYAP1 gene)', 'Gene or Genome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C1704926', 'PRP (ABCB6 wt Allele)', 'Gene or Genome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C3889430', 'PRP (CARD14 wt Allele)', 'Gene or Genome']]}

# %%
with open(os.path.join(outputs_path, "metamapped_conditions.txt"), 'w') as output:
    for key, val in mm_conditions.items():
        print(key)
#             output.write(key + "\t" + val[0] + "\t" + val[1] + "\t" + val[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
#       2 for key, val in mm_conditions.items():
#       3     if val:
# ----> 4         output.write(key + "\t" + val[0] + "\t" + val[1] + "\t" + val[2])
#
# TypeError: can only concatenate str (not "list") to str

# %%
cwd_absolute_path = os.path.dirname(os.getcwd())
outputs_folder = "outputs/version_2"
outputs_path = os.path.join(absolute_path, outputs_folder)
metamap_output = os.path.join(outputs_path, "metamapped_conditions.txt")
print(metamap_output)
# Out:
# /Users/Kamileh/Work/ISB/NCATS_BiomedicalTranslator/Projects/ClinicalTrials/ETL_Python/outputs/version_2/text.txt

# %%
mm_conditions
# Out:
# {'degenerative joint disease of the ankle': [[['C0409931'],
#    ['Degenerative joint disease of ankle (Osteoarthritis of ankle) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'kearns sayer': [[[], [], []]],
#  'hereditary angioedema - type 1': [[['C0398775'],
#    ['Hereditary angioedema - type 1 (Hereditary C1 esterase inhibitor deficiency - deficient factor) '],
#    ['Disease or Syndrome']],
#   [['C2717905'],
#    ['Hereditary angio oedema Type 1 (Hereditary Angioedema Types I and II) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'respiratory muscles': [[['C0021724'],
#    ['Respiratory Muscles (Structure of intercostal muscle) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C0035231'],
#    ['Respiratory Muscles '],
#    ['Body Part, Organ, or Organ Component']],
#   [[], [], []]],
#  'hepatic tumor': [[['C0023903'],
#    ['Hepatic tumour (Liver neoplasms) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'parent-child relationship': [[['C0030542'],
#    ['Parent-Child Relationship '],
#    ['Social Behavior']],
#   [['C1705423'],
#    ['Parent-Child Relationship (isa Relationship) '],
#    ['Idea or Concept']],
#   [['C2826537'],
#    ['Parent-Child Relationship (has_a Relationship) '],
#    ['Conceptual Entity']],
#   [[], [], []]],
#  'caesarean scar pregnancy': [[['C4289806'],
#    ['Cesarean Scar Pregnancy '],
#    ['Finding']],
#   [[], [], []]],
#  'sleep hygiene': [[['C4277672'], ['Sleep Hygiene '], ['Individual Behavior']],
#   [[], [], []]],
#  'ganglioneuroblastoma of central nervous system': [[['C2010420'],
#    ['Ganglioneuroblastoma of central nervous system (Central Nervous System Ganglioneuroblastoma) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'g6pd': [[['C0017757'],
#    ['G6PD (Glucosephosphate Dehydrogenase) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C1333652'], ['G6PD (G6PD gene) '], ['Gene or Genome']],
#   [['C2939465'],
#    ['G6PD (Deficiency of glucose-6-phosphate dehydrogenase) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'antineoplastic adverse reaction': [[['C0569491'],
#    ['Antineoplastic adverse reaction '],
#    ['Pathologic Function']],
#   [[], [], []]],
#  'isoflurane': [[['C0022180'],
#    ['ISOFLURANE (isoflurane) '],
#    ['Organic Chemical,Pharmacologic Substance']],
#   [[], [], []]],
#  'ocular tumor': [[['C0015414'],
#    ['Ocular Tumour (Eye Neoplasms) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'triple negative breast cancer, tnbc': [[['C3539878'],
#    ['TNBC - Triple-negative breast cancer (Triple Negative Breast Neoplasms) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'risk of bone fracture occurrences': [[['C0035647'],
#    ['Risk '],
#    ['Idea or Concept']],
#   [['C0016658'], ['Fracture of Bone (Fracture) '], ['Injury or Poisoning']],
#   [['C2745955'], ['Occurrences (Occurrence) '], ['Temporal Concept']],
#   [['C4552904'], ['risk (Subject Risk) '], ['Conceptual Entity']],
#   [['C0016658'], ['Fracture of Bone (Fracture) '], ['Injury or Poisoning']],
#   [['C2745955'], ['Occurrences (Occurrence) '], ['Temporal Concept']],
#   [[], [], []]],
#  'infants': [[['C0021270'], ['Infants (Infant) '], ['Age Group']],
#   [[], [], []]],
#  'attenuated or transient psychosis': [[['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [[], [], []]],
#  'erythema migrans': [[['C0014740'],
#    ['Erythema Migrans (Erythema Chronicum Migrans) '],
#    ['Disease or Syndrome']],
#   [['C0017677'],
#    ['erythema migrans (Glossitis, Benign Migratory) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'malignant pleural mesothelioma, advanced': [[['C0854889'],
#    ['Advanced Malignant pleural mesothelioma (Advanced Pleural Malignant Mesothelioma) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'degenerative': [[['C0011164'],
#    ['Degenerative (Abnormal degeneration) '],
#    ['Pathologic Function']],
#   [['C1880269'],
#    ['Degenerative (biologic degeneration) '],
#    ['Functional Concept']],
#   [[], [], []]],
#  'ataxia': [[['C0004134'], ['ATAXIA (Ataxia) '], ['Sign or Symptom']],
#   [['C0007758'], ['Ataxia (Cerebellar Ataxia) '], ['Disease or Syndrome']],
#   [['C4554639'], ['Ataxia (Ataxia, CTCAE 5.0) '], ['Finding']],
#   [[], [], []]],
#  'non alcoholic fatty liver': [[['C0400966'],
#    ['Nonalcoholic Fatty Liver (Non-alcoholic Fatty Liver Disease) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'myoma of uterus': [[['C0042133'],
#    ['uterus myoma (Uterine Fibroids) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'macular degeneration, choroidal neovascularization': [[['C0027686'],
#    ['Neovascularisation (Pathologic Neovascularization) '],
#    ['Pathologic Function']],
#   [['C0423425'],
#    ['Macular Choroidal degeneration (Macular choroidal sclerosis) '],
#    ['Finding']],
#   [[], [], []]],
#  'newborn, infant, disease': [[['C0021290'],
#    ['Infant, Newborn, Diseases (Neonatal disorder) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'viral; infection, coxsackie(virus)': [[['C0010246'],
#    ['Coxsackievirus Infection (Coxsackievirus Infections) '],
#    ['Disease or Syndrome']],
#   [['C0042776'], ['VIRUSES (Virus) '], ['Virus']],
#   [['C0010246'],
#    ['Coxsackievirus Infection (Coxsackievirus Infections) '],
#    ['Disease or Syndrome']],
#   [['C0521026'], ['viruses (Viral) '], ['Functional Concept']],
#   [[], [], []]],
#  'functional dysphonia': [[['C0264622'],
#    ['functional dysphonia (Psychogenic voice disorder) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'advanced recurrent ovarian tumors': [[['C0205179'],
#    ['Advanced (Advanced phase) '],
#    ['Qualitative Concept']],
#   [['C0521158'],
#    ['Recurrent Tumors (Recurrent tumor) '],
#    ['Neoplastic Process']],
#   [['C0205065'], ['Ovarian '], ['Body Part, Organ, or Organ Component']],
#   [['C0205179'], ['Advanced (Advanced phase) '], ['Qualitative Concept']],
#   [['C1455761'], ['Recurrent (Episodic) '], ['Temporal Concept']],
#   [['C0919267'],
#    ['Ovarian Tumors (ovarian neoplasm) '],
#    ['Neoplastic Process']],
#   [['C0205179'], ['Advanced (Advanced phase) '], ['Qualitative Concept']],
#   [['C2945760'], ['RECURRENT (Recurrent) '], ['Temporal Concept']],
#   [['C0919267'],
#    ['Ovarian Tumors (ovarian neoplasm) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'primary focal hyperhidrosis of the hands': [[['C1456132'],
#    ['Primary focal hyperhidrosis '],
#    ['Disease or Syndrome']],
#   [['C0018563'], ['Hands (Hand) '], ['Body Part, Organ, or Organ Component']],
#   [['C1456132'], ['Primary focal hyperhidrosis '], ['Disease or Syndrome']],
#   [['C1552914'], ['hand (hand - unit of measure) '], ['Quantitative Concept']],
#   [[], [], []]],
#  'gallbladder adenocarcinoma, biliary type': [[['C3273113'],
#    ['Gallbladder Adenocarcinoma, Biliary Type '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'sacral myelomeningocele': [[['C0521556'],
#    ['Sacral Myelomeningocele (Congenital sacral meningocele) '],
#    ['Congenital Abnormality']],
#   [[], [], []]],
#  'gender differences': [[['C0036866'],
#    ['Gender Differences (Sex Characteristics) '],
#    ['Organism Attribute']],
#   [[], [], []]],
#  'home blood pressure monitoring': [[['C1449681'],
#    ['Blood Pressure Monitoring, Home '],
#    ['Diagnostic Procedure']],
#   [[], [], []]],
#  'slippery pulse': [[['C0232117'],
#    ['PULSE (Pulse Rate) '],
#    ['Clinical Attribute']],
#   [['C0391850'], ['Pulse (Physiologic pulse) '], ['Physiologic Function']],
#   [['C1947910'], ['Pulse (Pulse phenomenon) '], ['Phenomenon or Process']],
#   [[], [], []]],
#  'neonatal phototherapy': [[['C0199741'],
#    ['Neonatal phototherapy (Phototherapy of newborn) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'gene transfer': [[['C0017296'],
#    ['Gene transfer (gene therapy) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1517499'], ['Gene Transfer '], ['Molecular Biology Research Technique']],
#   [[], [], []]],
#  'thoracic endovascular repair': [[['C0524425'],
#    ['Endovascular (inside the blood vessel) '],
#    ['Body Location or Region']],
#   [['C0043240'], ['Repair, NOS (Wound Healing) '], ['Organism Function']],
#   [['C0524425'],
#    ['Endovascular (inside the blood vessel) '],
#    ['Body Location or Region']],
#   [['C0374711'],
#    ['Repair, NOS (Surgical repair) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0524425'],
#    ['Endovascular (inside the blood vessel) '],
#    ['Body Location or Region']],
#   [['C4319951'], ['Repair '], ['Functional Concept']],
#   [[], [], []]],
#  'drug binding to dat receptors': [[['C0678749'],
#    ['drug binding '],
#    ['Physiologic Function']],
#   [['C1439340'],
#    ['DAT (SLC6A3 protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Biologically Active Substance']],
#   [['C0597357'],
#    ['Receptors (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C0678749'], ['drug binding '], ['Physiologic Function']],
#   [['C3813713'], ['DAT (SLC6A3 wt Allele) '], ['Gene or Genome']],
#   [['C0597357'],
#    ['Receptors (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1145667'], ['Binding (Binding action) '], ['Activity']],
#   [['C1439340'],
#    ['DAT (SLC6A3 protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Biologically Active Substance']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1145667'], ['Binding (Binding action) '], ['Activity']],
#   [['C3813713'], ['DAT (SLC6A3 wt Allele) '], ['Gene or Genome']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1167622'],
#    ['Binding (Binding (Molecular Function)) '],
#    ['Molecular Function']],
#   [['C1439340'],
#    ['DAT (SLC6A3 protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Biologically Active Substance']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1167622'],
#    ['Binding (Binding (Molecular Function)) '],
#    ['Molecular Function']],
#   [['C3813713'], ['DAT (SLC6A3 wt Allele) '], ['Gene or Genome']],
#   [[], [], []]],
#  'periodontal disease and caries': [[['C0031090'],
#    ['PERIODONTAL DISEASE (Periodontal Diseases) '],
#    ['Disease or Syndrome']],
#   [['C0011334'], ['Caries (Dental caries) '], ['Disease or Syndrome']],
#   [['C0031090'],
#    ['PERIODONTAL DISEASE (Periodontal Diseases) '],
#    ['Disease or Syndrome']],
#   [['C0333519'],
#    ['Caries (Caries (morphologic abnormality)) '],
#    ['Disease or Syndrome']],
#   [['C1559300'],
#    ['Periodontal Disease (Periodontal Disease, CTCAE) '],
#    ['Finding']],
#   [['C0011334'], ['Caries (Dental caries) '], ['Disease or Syndrome']],
#   [['C1559300'],
#    ['Periodontal Disease (Periodontal Disease, CTCAE) '],
#    ['Finding']],
#   [['C0333519'],
#    ['Caries (Caries (morphologic abnormality)) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'pulmonary mac': [[['C0024109'],
#    ['pulmonary (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C0024109'],
#    ['pulmonary (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [['C2707265'],
#    ['Pulmonary (Pulmonary:-:Point in time:^Patient:-) '],
#    ['Clinical Attribute']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C2707265'],
#    ['Pulmonary (Pulmonary:-:Point in time:^Patient:-) '],
#    ['Clinical Attribute']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [['C2709248'],
#    ['Pulmonary (Pulmonary (qualifier value)) '],
#    ['Qualitative Concept']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C2709248'],
#    ['Pulmonary (Pulmonary (qualifier value)) '],
#    ['Qualitative Concept']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [['C4522268'], ['Pulmonary (Pulmonary (intended site)) '], ['Finding']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C4522268'], ['Pulmonary (Pulmonary (intended site)) '], ['Finding']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [[], [], []]],
#  'c-staged hepatocellular carcinoma in bclc classification': [[['C3899977'],
#    ['BCLC Stage C Hepatocellular Carcinoma '],
#    ['Neoplastic Process']],
#   [['C0008902'], ['Classification '], ['Classification']],
#   [['C3899977'],
#    ['BCLC Stage C Hepatocellular Carcinoma '],
#    ['Neoplastic Process']],
#   [['C0008903'], ['classification (Taxonomic) '], ['Functional Concept']],
#   [['C3899977'],
#    ['BCLC Stage C Hepatocellular Carcinoma '],
#    ['Neoplastic Process']],
#   [['C0678229'],
#    ['classification (Classification of information) '],
#    ['Occupational Activity']],
#   [[], [], []]],
#  'respiratory distress syndrome, pediatric': [[['C5392184'],
#    ['Respiratory Distress Syndrome, Pediatric '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'bloodpressure': [[['C0005823'],
#    ['BLOOD PRESSURE (Blood Pressure) '],
#    ['Organism Function']],
#   [['C1271104'], ['Blood Pressure (Blood pressure finding) '], ['Finding']],
#   [['C1272641'],
#    ['Blood pressure (Systemic arterial pressure) '],
#    ['Finding']],
#   [[], [], []]],
#  'hepatocyte receptor': [[['C0227525'], ['Hepatocyte '], ['Cell']],
#   [['C0597357'],
#    ['Receptor (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C0669372'],
#    ['Hepatocyte NOS (NOS2A protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0597357'],
#    ['Receptor (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [[], [], []]],
#  'deep wrinkles of the forehead': [[['C0205125'],
#    ['DEEP (Deep (qualifier value)) '],
#    ['Spatial Concept']],
#   [['C1997891'], ['Wrinkle of forehead (Rhytide of forehead) '], ['Finding']],
#   [['C4318566'], ['Deep (Deep Resection Margin) '], ['Clinical Attribute']],
#   [['C1997891'], ['Wrinkle of forehead (Rhytide of forehead) '], ['Finding']],
#   [[], [], []]],
#  'clinical decision support system': [[['C0525070'],
#    ['Clinical Decision Support System (Decision Support Systems, Clinical) '],
#    ['Intellectual Product']],
#   [[], [], []]],
#  'malignant ovarian endometrioid tumor': [[['C1518231'],
#    ['Malignant Ovarian Endometrioid Tumor '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'severe marrow failure': [[['C0205082'],
#    ['SEVERE (Severe (severity modifier)) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [[], [], []]],
#  'diagnoses that require stem cell transplant': [[['C0011900'],
#    ['Diagnoses (Diagnosis) '],
#    ['Diagnostic Procedure']],
#   [['C1504389'],
#    ['Stem Cell Transplant (Stem cell transplant) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'emotional disorder': [[['C0233459'],
#    ['Emotional disorder '],
#    ['Mental or Behavioral Dysfunction']],
#   [[], [], []]],
#  'mannose-binding lectin complement pathway': [[['C1138407'],
#    ['Complement Pathway, Mannose-Binding Lectin '],
#    ['Molecular Function']],
#   [[], [], []]],
#  'cervical neoplasia': [[['C0007873'],
#    ['cervical Neoplasia (Uterine Cervical Neoplasm) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'hormonal changes': [[['C1134488'],
#    ['hormonal changes (Hormonal Change) '],
#    ['Finding']],
#   [[], [], []]],
#  'head and neck surgeries': [[['C1512343'],
#    ['Head and Neck Surgery '],
#    ['Health Care Activity']],
#   [[], [], []]],
#  'hemolytic-uremic syndrome, atypical': [[['C2931788'],
#    ['Atypical haemolytic uraemic syndrome (Atypical Hemolytic Uremic Syndrome) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'abdominal aortic aneurysms with challenging anatomy': [[['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0798503'],
#    ['Challenge (Challenge:Type:Point in time:^Patient:Nominal) '],
#    ['Clinical Attribute']],
#   [['C0002808'],
#    ['Anatomy (Science of Anatomy) '],
#    ['Biomedical Occupation or Discipline']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0798503'],
#    ['Challenge (Challenge:Type:Point in time:^Patient:Nominal) '],
#    ['Clinical Attribute']],
#   [['C0700276'], ['Anatomy (Anatomic structures) '], ['Anatomical Structure']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0798503'],
#    ['Challenge (Challenge:Type:Point in time:^Patient:Nominal) '],
#    ['Clinical Attribute']],
#   [['C1384516'], ['anatomy (Anatomy aspects) '], ['Qualitative Concept']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0805586'], ['Challenge '], ['Health Care Activity']],
#   [['C0002808'],
#    ['Anatomy (Science of Anatomy) '],
#    ['Biomedical Occupation or Discipline']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0805586'], ['Challenge '], ['Health Care Activity']],
#   [['C0700276'], ['Anatomy (Anatomic structures) '], ['Anatomical Structure']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0805586'], ['Challenge '], ['Health Care Activity']],
#   [['C1384516'], ['anatomy (Anatomy aspects) '], ['Qualitative Concept']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C3274764'],
#    ['Challenge (Proficiency Testing Challenge) '],
#    ['Conceptual Entity']],
#   [['C0002808'],
#    ['Anatomy (Science of Anatomy) '],
#    ['Biomedical Occupation or Discipline']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C3274764'],
#    ['Challenge (Proficiency Testing Challenge) '],
#    ['Conceptual Entity']],
#   [['C0700276'], ['Anatomy (Anatomic structures) '], ['Anatomical Structure']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C3274764'],
#    ['Challenge (Proficiency Testing Challenge) '],
#    ['Conceptual Entity']],
#   [['C1384516'], ['anatomy (Anatomy aspects) '], ['Qualitative Concept']],
#   [[], [], []]],
#  'central blood pressure': [[['C0205099'],
#    ['CENTRAL (Central) '],
#    ['Spatial Concept']],
#   [['C0005823'], ['BLOOD PRESSURE (Blood Pressure) '], ['Organism Function']],
#   [['C0205099'], ['CENTRAL (Central) '], ['Spatial Concept']],
#   [['C1271104'], ['Blood Pressure (Blood pressure finding) '], ['Finding']],
#   [['C0205099'], ['CENTRAL (Central) '], ['Spatial Concept']],
#   [['C1272641'],
#    ['Blood pressure (Systemic arterial pressure) '],
#    ['Finding']],
#   [['C1879652'], ['Central - (Central Minus) '], ['Laboratory Procedure']],
#   [['C0005823'], ['BLOOD PRESSURE (Blood Pressure) '], ['Organism Function']],
#   [['C1879652'], ['Central - (Central Minus) '], ['Laboratory Procedure']],
#   [['C1271104'], ['Blood Pressure (Blood pressure finding) '], ['Finding']],
#   [['C1879652'], ['Central - (Central Minus) '], ['Laboratory Procedure']],
#   [['C1272641'],
#    ['Blood pressure (Systemic arterial pressure) '],
#    ['Finding']],
#   [[], [], []]],
#  'vaccine': [[['C0042210'],
#    ['Vaccine (Vaccines) '],
#    ['Amino Acid, Peptide, or Protein,Immunologic Factor,Pharmacologic Substance']],
#   [['C5399710'], ['Vaccine (Vaccine '], ['APC', 'Pharmacologic Substance']],
#   [[], [], []]],
#  'lower grade glioma, recurrent': [[['C4688341'],
#    ['Recurrent Low-Grade Glioma (Recurrent WHO Grade II Glioma) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'male sterilization': [[['C0024559'],
#    ['Male sterilisation (Male sterilization) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'diabetes mellitus type 2 without complication': [[['C0494290'],
#    ['Type 2 diabetes mellitus without complication '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'body contouring surgery': [[['C2224569'],
#    ['Surgery, Body Contouring (Body Contouring) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'parenteral nutrition (no primary condition studied)': [[['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C0557651'],
#    ['Study (Room of building - Study) '],
#    ['Manufactured Object']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C2603343'], ['Study '], ['Research Activity']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0205225'], ['Primary '], ['Qualitative Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439612'],
#    ['Primary (True primary (qualifier value)) '],
#    ['Temporal Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439631'],
#    ['Primary (Primary operation) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0677930'], ['primary (Primary Neoplasm) '], ['Neoplastic Process']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C0557651'],
#    ['Study (Room of building - Study) '],
#    ['Manufactured Object']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C2603343'], ['Study '], ['Research Activity']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0205225'], ['Primary '], ['Qualitative Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439612'],
#    ['Primary (True primary (qualifier value)) '],
#    ['Temporal Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439631'],
#    ['Primary (Primary operation) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0677930'], ['primary (Primary Neoplasm) '], ['Neoplastic Process']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [[], [], []]],
#  'lung structure determination': [[['C0024109'],
#    ['Lung structure (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C0521095'], ['Determination (Determined by) '], ['Qualitative Concept']],
#   [['C0024109'],
#    ['Lung structure (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C1148554'],
#    ['determination (Determination Aspects) '],
#    ['Laboratory Procedure']],
#   [[], [], []]],
#  'immunologically-induced lung disease': [[['C0205263'],
#    ['Induced (Induce (action)) '],
#    ['Functional Concept']],
#   [['C0024115'], ['Disease, Lung (Lung diseases) '], ['Disease or Syndrome']],
#   [[], [], []]],
#  'medulloblastoma, group 4': [[['C4330666'],
#    ['Medulloblastoma, group 4 (Medulloblastoma, Non-WNT/Non-SHH, Group 4) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'death, sudden,cardiac': [[['C0085298'],
#    ['Death, Sudden, Cardiac (Sudden Cardiac Death) '],
#    ['Pathologic Function']],
#   [[], [], []]],
#  'the clinical application guide of conebeam breast ct': [[['C0681467'],
#    ['clinical guide '],
#    ['Intellectual Product']],
#   [['C0185125'],
#    ['Application (Application procedure) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C1947919'],
#    ['Application (Application (Document)) '],
#    ['Intellectual Product']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C2347934'],
#    ['Application (Regulatory Application) '],
#    ['Intellectual Product']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C3539080'],
#    ['APPLICATION (Application Dosing Unit) '],
#    ['Quantitative Concept']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C4048755'], ['Application (Apply) '], ['Functional Concept']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [[], [], []]],
#  'beta rhythm': [[['C0005167'],
#    ['Beta Rhythm '],
#    ['Organ or Tissue Function']],
#   [[], [], []]],
#  'fracture of long bones': [[['C0016658'],
#    ['Fracture of bones NOS (Fracture) '],
#    ['Injury or Poisoning']],
#   [['C0205166'], ['LONG (Long) '], ['Qualitative Concept']],
#   [['C0016658'],
#    ['Fracture of bones NOS (Fracture) '],
#    ['Injury or Poisoning']],
#   [['C1706317'], ['Long (Long Variable) '], ['Qualitative Concept']],
#   [['C0016658'],
#    ['Fracture of bones NOS (Fracture) '],
#    ['Injury or Poisoning']],
#   [['C5238697'], ['Long (Long Heart Murmur) '], ['Finding']],
#   [[], [], []]],
#  'target controlled infusion': [[['C1521840'],
#    ['Target '],
#    ['Functional Concept']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [[], [], []]],
#  'elite athletes': [[['C5392984'], ['Elite Athletes '], ['Population Group']],
#   [[], [], []]],
#  'primary': [[['C0205225'], ['Primary '], ['Qualitative Concept']],
#   [['C0439612'],
#    ['Primary (True primary (qualifier value)) '],
#    ['Temporal Concept']],
#   [['C0439631'],
#    ['Primary (Primary operation) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0677930'], ['primary (Primary Neoplasm) '], ['Neoplastic Process']],
#   [[], [], []]],
#  'spina bifida and anencephaly': [[['C1845026'],
#    ['Anencephaly-Spina Bifida (Neural tube defects X-linked) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'pre-term birth': [[['C0151526'],
#    ['Pre-Term (Premature Birth) '],
#    ['Pathologic Function']],
#   [['C0005615'], ['Birth '], ['Organism Function']],
#   [['C0151526'], ['Pre-Term (Premature Birth) '], ['Pathologic Function']],
#   [['C1148523'], ['Birth (Childbirth) '], ['Organism Function']],
#   [['C0151526'], ['Pre-Term (Premature Birth) '], ['Pathologic Function']],
#   [['C1550722'],
#    ['birth (Entity Name Part Qualifier - birth) '],
#    ['Intellectual Product']],
#   [['C0151526'], ['Pre-Term (Premature Birth) '], ['Pathologic Function']],
#   [['C3245487'], ['birth (Name Given at Birth) '], ['Intellectual Product']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C0233324'], ['Term (Term Birth) '], ['Organism Function']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C1515273'], ['Term (Term (temporal)) '], ['Temporal Concept']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C1705313'], ['Term (Term (lexical)) '], ['Idea or Concept']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C2826302'], ['TERM (Reported Term) '], ['Intellectual Product']],
#   [['C0332152'], ['Pre (Before) '], ['Temporal Concept']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [['C0740175'], ['Pre (Before values) '], ['Qualitative Concept']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [['C2257086'],
#    ['PRE (photoreactivating enzyme activity) '],
#    ['Genetic Function']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [['C3669034'], ['PRE (Pure Spanish horse breed (organism)) '], ['Mammal']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [[], [], []]],
#  'gr\x1a\x1anblad-stranberg disease (pseudoxanthoma elasticum)': [[['C1552950'],
#    [],
#    ['gr', 'Quantitative Concept']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0033847'],
#    ['PSEUDOXANTHOMA ELASTICUM (Pseudoxanthoma Elasticum) '],
#    ['Disease or Syndrome']],
#   [['C1552950'], [], ['gr', 'Quantitative Concept']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0473583'],
#    ['pseudoxanthoma elasticum (Nevus elasticus) '],
#    ['Neoplastic Process']],
#   [['C1552950'], [], ['gr', 'Quantitative Concept']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C1412081'],
#    ['pseudoxanthoma elasticum (ABCC6 gene) '],
#    ['Gene or Genome']],
#   [['C4721873'],
#    ['GR (Glutathione Reductase, Mitochondrial, Human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0033847'],
#    ['PSEUDOXANTHOMA ELASTICUM (Pseudoxanthoma Elasticum) '],
#    ['Disease or Syndrome']],
#   [['C4721873'],
#    ['GR (Glutathione Reductase, Mitochondrial, Human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0473583'],
#    ['pseudoxanthoma elasticum (Nevus elasticus) '],
#    ['Neoplastic Process']],
#   [['C4721873'],
#    ['GR (Glutathione Reductase, Mitochondrial, Human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C1412081'],
#    ['pseudoxanthoma elasticum (ABCC6 gene) '],
#    ['Gene or Genome']],
# ...
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   ...],
#  ...}

# %%
"""
-I = return CUIs/identifiers
-i = ignore word order
-C = relaxed model
-z = term processing
--sldi = read each term in list separately, do not lump into large phrase

https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/ListOfTerms.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/TermProcessing.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/MM_2016_Usage.pdf
"""
args = ['--sldi -i -I -C -z -f']
# args = ['-I --prune 5']
form = {}
form['APIText'] = chunk
form['KSOURCE'] = ksource
form['COMMAND_ARGS'] = args
headers = {'Accept': 'application/json'}

for chunk in chunked_conditions_unmapped[:2]:
#     print(chunk[:10])
#     chunk = chunk[:10]
    service_ticket = get_ticket(CAS_SERVERURL, apikey, serviceurl)
#     chunk = chunk[:5] # demo for testing
    form['APIText'] = chunk
    params = {'ticket': service_ticket}
    response = s.post(serviceurl, form, headers=headers, params=params, allow_redirects=False)
    if response.status_code == 302:
        newurl = s.get_redirect_target(response)
        response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)
    print(response.text)
# Out:
# /dmzfiler/II_Group/MetaMap2020/public_mm/bin/SKRrun.20 /dmzfiler/II_Group/MetaMap2020/public_mm/bin/metamap20.BINARY.Linux --lexicon db -Z 2020AB --silent -i -I -C -z --sldi
# Processing USER.tx.1: ankle foot injury
#
# Phrase: ankle foot injury
# Meta Mapping (1000):
#   1000   C0348772:ankle foot injury (injuries to the ankle and foot) [Injury or Poisoning]
# Processing USER.tx.1: knowledge about condom use
#
# Phrase: knowledge about condom use
# Meta Mapping (783):
#    770   C0376554:Knowledge [Intellectual Product]
#    666   C0679782:Condom use (condom use) [Individual Behavior]
# Processing USER.tx.1: floor of mouth squamous cell carcinoma
#
# Phrase: floor of mouth squamous cell carcinoma
# Meta Mapping (1000):
#   1000   C0280300:Floor of Mouth Squamous Cell Carcinoma (Squamous cell carcinoma of floor of mouth) [Neoplastic Process]
# Processing USER.tx.1: tendinoses, rotator cuff
#
# Phrase: tendinoses, rotator cuff
# Meta Mapping (1000):
#   1000   C4280057:Tendinoses, Rotator Cuff (Rotator Cuff Tendinosis) [Injury or Poisoning]
# Processing USER.tx.1: trauma patients in icu
#
# Phrase: trauma patients in icu
# Meta Mapping (783):
#    819   C4047661:Trauma ICU (Trauma intensive care unit) [Health Care Related Organization,Manufactured Object]
#    770   C0030705:Patients [Patient or Disabled Group]
# Processing USER.tx.1: noninsulin-dependent diabetes mellitus
#
# Phrase: noninsulin-dependent diabetes mellitus
# Meta Mapping (1000):
#   1000   C0011849:non insulin dependent diabetes Mellitus (Diabetes Mellitus) [Disease or Syndrome]
# Meta Mapping (1000):
#   1000   C0011860:Noninsulin Dependent Diabetes Mellitus (Diabetes Mellitus, Non-Insulin-Dependent) [Disease or Syndrome]
# Meta Mapping (1000):
#   1000   C2984301:non insulin dependent diabetes mellitus (Type II Diabetes Mellitus Pathway) [Conceptual Entity]
# Processing USER.tx.1: rabies in animals
#
# Phrase: rabies in animals
# Meta Mapping (1000):
#   1000   C1301949:Rabies in animals (Non-human rabies) [Disease or Syndrome]
# Processing USER.tx.1: stage iiia soft tissue sarcoma of the trunk and extremities ajcc v8
#
# Phrase: stage iiia soft tissue sarcoma of the trunk and extremities ajcc v8
# Meta Mapping (1000):
#   1000   C4526905:Stage IIIA Soft Tissue Sarcoma of the Trunk and Extremities AJCC v8 [Neoplastic Process]
# Processing USER.tx.1: mild persistent asthma
#
# Phrase: mild persistent asthma
# Meta Mapping (1000):
#   1000   C1960046:Asthma, mild persistent (Mild persistent asthma) [Disease or Syndrome]
# Processing USER.tx.1: bacteremia caused by gram-negative bacteria
#
# Phrase: bacteremia caused by gram-negative bacteria
# Meta Mapping (1000):
#   1000   C3495091:Bacteremia caused by Gram-negative bacteria [Disease or Syndrome]
# Processing USER.tx.1: acquired bone marrow aplasia
#
# Phrase: acquired bone marrow aplasia
# Meta Mapping (916):
#    604   C0439661:Acquired (Acquired (qualifier value)) [Qualitative Concept]
#    909   C0002874:bone marrow aplasia (Aplastic Anemia) [Disease or Syndrome]
# Meta Mapping (916):
#    604   C0439661:Acquired (Acquired (qualifier value)) [Qualitative Concept]
#    909   C1368107:Bone Marrow Aplasia (Aplastic bone marrow) [Disease or Syndrome]
# Meta Mapping (916):
#    604   C3245488:acquired (Acquired Name) [Intellectual Product]
#    909   C0002874:bone marrow aplasia (Aplastic Anemia) [Disease or Syndrome]
# Meta Mapping (916):
#    604   C3245488:acquired (Acquired Name) [Intellectual Product]
#    909   C1368107:Bone Marrow Aplasia (Aplastic bone marrow) [Disease or Syndrome]
# Processing USER.tx.1: psychogenic non-epileptic seizures, motivational interviewing
#
# Phrase: psychogenic non-epileptic seizures, motivational interviewing
# Meta Mapping (892):
#    623   C0683474:Motivational Interviewing [Therapeutic or Preventive Procedure]
#    871   C1142430:Psychogenic Non-Epileptic Seizure (Psychogenic seizure) [Mental or Behavioral Dysfunction]
# Processing USER.tx.1: post-operative pulmonary complications
#
# Phrase: post-operative pulmonary complications
# Meta Mapping (901):
#    666   C0032790:Postoperative (Postoperative Period) [Temporal Concept]
#    833   C0281169:pulmonary complications (Pulmonary Complication) [Pathologic Function]
# Meta Mapping (901):
#    666   C0241311:POST OPERATIVE (post operative (finding)) [Finding]
#    833   C0281169:pulmonary complications (Pulmonary Complication) [Pathologic Function]
# Meta Mapping (901):
#    604   C0024109:pulmonary (Lung) [Body Part, Organ, or Organ Component]
#    881   C0032787:complications postoperative (Postoperative Complications) [Pathologic Function]
# Meta Mapping (901):
#    604   C2707265:Pulmonary (Pulmonary:-:Point in time:^Patient:-) [Clinical Attribute]
#    881   C0032787:complications postoperative (Postoperative Complications) [Pathologic Function]
# Meta Mapping (901):
#    604   C2709248:Pulmonary (Pulmonary (qualifier value)) [Qualitative Concept]
#    881   C0032787:complications postoperative (Postoperative Complications) [Pathologic Function]
# Meta Mapping (901):
#    604   C4522268:Pulmonary (Pulmonary (intended site)) [Finding]
#    881   C0032787:complications postoperative (Postoperative Complications) [Pathologic Function]
# Processing USER.tx.1: acute noninfectious posterior, intermediate, or pan uveitis
#
# Phrase: acute noninfectious posterior, intermediate, or pan uveitis
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C0205103:INTERMEDIATE (Intermediate) [Spatial Concept]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C0205103:INTERMEDIATE (Intermediate) [Spatial Concept]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C0205103:INTERMEDIATE (Intermediate) [Spatial Concept]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C1550465:Intermediate (Observation Interpretation - intermediate) [Laboratory or Test Result]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C1550465:Intermediate (Observation Interpretation - intermediate) [Laboratory or Test Result]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C1550465:Intermediate (Observation Interpretation - intermediate) [Laboratory or Test Result]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C2827755:INTERMEDIATE (Antimicrobial Intermediate Susceptibility Result) [Laboratory or Test Result]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C2827755:INTERMEDIATE (Antimicrobial Intermediate Susceptibility Result) [Laboratory or Test Result]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C2827755:INTERMEDIATE (Antimicrobial Intermediate Susceptibility Result) [Laboratory or Test Result]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C3889971:Intermediate (Intermediate Mitosis-Karyorrhexis Index) [Quantitative Concept]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C3889971:Intermediate (Intermediate Mitosis-Karyorrhexis Index) [Quantitative Concept]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C3889971:Intermediate (Intermediate Mitosis-Karyorrhexis Index) [Quantitative Concept]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C4722218:Intermediate (International Metastatic Renal Cell Carcinoma Database Consortium (IMDC) Criteria - Intermediate-Risk Group) [Intellectual Product]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C4722218:Intermediate (International Metastatic Renal Cell Carcinoma Database Consortium (IMDC) Criteria - Intermediate-Risk Group) [Intellectual Product]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C4722218:Intermediate (International Metastatic Renal Cell Carcinoma Database Consortium (IMDC) Criteria - Intermediate-Risk Group) [Intellectual Product]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C5202835:Intermediate (IPSS-R Risk Category Intermediate) [Finding]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C5202835:Intermediate (IPSS-R Risk Category Intermediate) [Finding]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C0205178:ACUTE (acute) [Temporal Concept]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C5202835:Intermediate (IPSS-R Risk Category Intermediate) [Finding]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C0205103:INTERMEDIATE (Intermediate) [Spatial Concept]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C0205103:INTERMEDIATE (Intermediate) [Spatial Concept]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C0205103:INTERMEDIATE (Intermediate) [Spatial Concept]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C1550465:Intermediate (Observation Interpretation - intermediate) [Laboratory or Test Result]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C1550465:Intermediate (Observation Interpretation - intermediate) [Laboratory or Test Result]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C1550465:Intermediate (Observation Interpretation - intermediate) [Laboratory or Test Result]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C2827755:INTERMEDIATE (Antimicrobial Intermediate Susceptibility Result) [Laboratory or Test Result]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C2827755:INTERMEDIATE (Antimicrobial Intermediate Susceptibility Result) [Laboratory or Test Result]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C2827755:INTERMEDIATE (Antimicrobial Intermediate Susceptibility Result) [Laboratory or Test Result]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C3889971:Intermediate (Intermediate Mitosis-Karyorrhexis Index) [Quantitative Concept]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C3889971:Intermediate (Intermediate Mitosis-Karyorrhexis Index) [Quantitative Concept]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C3889971:Intermediate (Intermediate Mitosis-Karyorrhexis Index) [Quantitative Concept]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C4722218:Intermediate (International Metastatic Renal Cell Carcinoma Database Consortium (IMDC) Criteria - Intermediate-Risk Group) [Intellectual Product]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C4722218:Intermediate (International Metastatic Renal Cell Carcinoma Database Consortium (IMDC) Criteria - Intermediate-Risk Group) [Intellectual Product]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C4722218:Intermediate (International Metastatic Renal Cell Carcinoma Database Consortium (IMDC) Criteria - Intermediate-Risk Group) [Intellectual Product]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C5202835:Intermediate (IPSS-R Risk Category Intermediate) [Finding]
#    581   C0085999:Pan (Pan Genus) [Mammal]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C5202835:Intermediate (IPSS-R Risk Category Intermediate) [Finding]
#    581   C0424925:PAN (Punjabi language) [Language]
# Meta Mapping (774):
#    581   C1551345:ACUTE (acute inpatient encounter) [Health Care Activity]
#    638   C5396634:Non-infectious posterior uveitis [Disease or Syndrome]
#    748   C5202835:Intermediate (IPSS-R Risk Category Intermediate) [Finding]
#    581   C3887654:PAN (POLYARTERITIS NODOSA, CHILDHOOD-ONSET) [Disease or Syndrome]
# Processing USER.tx.1: relapsing multiple sclerosis (rms)
#
# Phrase: relapsing multiple sclerosis
# Meta Mapping (901):
#    790   C0035020:Relapsing (Relapse) [Phenomenon or Process]
#    882   C0026769:MULTIPLE SCLEROSIS (Multiple Sclerosis) [Disease or Syndrome]
# Meta Mapping (901):
#    790   C0205336:relapsing (Relapsing course) [Temporal Concept]
#    882   C0026769:MULTIPLE SCLEROSIS (Multiple Sclerosis) [Disease or Syndrome]
# Processing USER.tx.1: long-term outcome
#
# Phrase: long-term outcome
# Meta Mapping (901):
#    716   C0443252:Long Term (Long-term) [Temporal Concept]
#    790   C1274040:Outcome (Result) [Functional Concept]
# Processing USER.tx.1: hemophilia a with inhibitors
#
# Phrase: hemophilia a with inhibitors
# Meta Mapping (988):
#    988   C0472802:Hemophilia A with inhibitor (Hereditary factor VIII deficiency disease with inhibitor) [Disease or Syndrome]
# Processing USER.tx.1: recurrent endometrioid adenocarcinoma
#
# Phrase: recurrent endometrioid adenocarcinoma
# Meta Mapping (1000):
#   1000   C0862493:Recurrent Endometrioid Adenocarcinoma [Neoplastic Process]
# Processing USER.tx.1: covid 19 positive
#
# Phrase: covid 19 positive
# Meta Mapping (901):
#    716   C5203670:COVID 19 (COVID-19) [Disease or Syndrome]
#    790   C0439178:% Positive (percent positive cells) [Quantitative Concept]
# Meta Mapping (901):
#    716   C5203670:COVID 19 (COVID-19) [Disease or Syndrome]
#    790   C1446409:Positive [Finding]
# Meta Mapping (901):
#    716   C5203670:COVID 19 (COVID-19) [Disease or Syndrome]
#    790   C1514241:POSITIVE (Positive Finding) [Finding]
# Meta Mapping (901):
#    716   C5203670:COVID 19 (COVID-19) [Disease or Syndrome]
#    790   C2825490:Positive (Positive Charge) [Qualitative Concept]
# Meta Mapping (901):
#    716   C5203670:COVID 19 (COVID-19) [Disease or Syndrome]
#    790   C3812269:Positive (Positive Number) [Quantitative Concept]
# Meta Mapping (901):
#    716   C5203670:COVID 19 (COVID-19) [Disease or Syndrome]
#    790   C4727483:Positive (BRAF Gene Rearrangement) [Cell or Molecular Dysfunction]
# Meta Mapping (901):
#    716   C5203676:COVID-19 (2019 novel coronavirus) [Virus]
#    790   C0439178:% Positive (percent positive cells) [Quantitative Concept]
# Meta Mapping (901):
#    716   C5203676:COVID-19 (2019 novel coronavirus) [Virus]
#    790   C1446409:Positive [Finding]
# Meta Mapping (901):
#    716   C5203676:COVID-19 (2019 novel coronavirus) [Virus]
#    790   C1514241:POSITIVE (Positive Finding) [Finding]
# Meta Mapping (901):
#    716   C5203676:COVID-19 (2019 novel coronavirus) [Virus]
#    790   C2825490:Positive (Positive Charge) [Qualitative Concept]
# Meta Mapping (901):
#    716   C5203676:COVID-19 (2019 novel coronavirus) [Virus]
#    790   C3812269:Positive (Positive Number) [Quantitative Concept]
# Meta Mapping (901):
#    716   C5203676:COVID-19 (2019 novel coronavirus) [Virus]
#    790   C4727483:Positive (BRAF Gene Rearrangement) [Cell or Molecular Dysfunction]
# Processing USER.tx.1: a known allergy to chlorohexidine alcohol or shellfis
#
# Phrase: a known allergy to chlorohexidine alcohol or shellfis
# Meta Mapping (731):
#    578   C0439508:/a (per year) [Temporal Concept]
#    578   C0205309:Known [Qualitative Concept]
#    793   C0740909:Allergy to alcohol (Allergy to ethanol) [Pathologic Function]
# Meta Mapping (731):
#    578   C1553039:[a] (Atto) [Quantitative Concept]
#    578   C0205309:Known [Qualitative Concept]
#    793   C0740909:Allergy to alcohol (Allergy to ethanol) [Pathologic Function]
# Processing USER.tx.1: ocular surface
#
# Phrase: ocular surface
# Meta Mapping (888):
#    833   C0015392:Ocular (Eye) [Body Part, Organ, or Organ Component]
#    833   C0205148:SURFACE (Surface) [Spatial Concept]
# Meta Mapping (888):
#    833   C0042789:Ocular (Vision) [Organism Function]
#    833   C0205148:SURFACE (Surface) [Spatial Concept]
# Meta Mapping (888):
#    833   C0700042:Ocular (Orbital region) [Body Location or Region]
#    833   C0205148:SURFACE (Surface) [Spatial Concept]
# Meta Mapping (888):
#    833   C1299003:Ocular (Ocular (qualifier)) [Functional Concept]
#    833   C0205148:SURFACE (Surface) [Spatial Concept]
# Meta Mapping (888):
#    833   C4521296:Ocular (Ocular (intended site)) [Finding]
#    833   C0205148:SURFACE (Surface) [Spatial Concept]
# Processing USER.tx.1: antisocial behavior
#
# Phrase: antisocial behavior
# Meta Mapping (1000):
#   1000   C0233523:anti-social behaviour (Antisocial behavior) [Mental or Behavioral Dysfunction]
# Meta Mapping (1000):
#   1000   C2919119:Antisocial behavior (Encounter due to antisocial behavior) [Finding]
# Processing USER.tx.1: elopement
#
# Phrase: elopement
# Meta Mapping (1000):
#   1000   C3840807:Elopement [Daily or Recreational Activity]
# Processing USER.tx.1: perforation of the colon
#
# Phrase: perforation of the colon
# Meta Mapping (1000):
#   1000   C0347646:Perforation of the colon (Perforation of colon) [Disease or Syndrome]
# Processing USER.tx.1: varus; talipes
#
# Phrase: varus; talipes
# Meta Mapping (1000):
#    944   C0009081:Talipes varus (Congenital clubfoot) [Congenital Abnormality]
# Meta Mapping (1000):
#    944   C0158722:Talipes varus (Congenital talipes varus) [Congenital Abnormality]
# Meta Mapping (1000):
#    944   C4551569:Talipes Varus [Anatomical Abnormality]
# Processing USER.tx.1: histologically confirmed medulloblastoma
#
# Phrase: histologically confirmed medulloblastoma
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0521093:confirmed (Confirmed by) [Qualitative Concept]
#    790   C0025149:MEDULLOBLASTOMA (Medulloblastoma) [Neoplastic Process]
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0521093:confirmed (Confirmed by) [Qualitative Concept]
#    790   C0278510:Medulloblastoma (Childhood Medulloblastoma) [Neoplastic Process]
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0521093:confirmed (Confirmed by) [Qualitative Concept]
#    790   C0278876:Medulloblastoma (Adult Medulloblastoma) [Neoplastic Process]
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0521093:confirmed (Confirmed by) [Qualitative Concept]
#    790   C4330668:Medulloblastoma, Not Otherwise Specified [Neoplastic Process]
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0750484:Confirmed (Confirmation) [Finding]
#    790   C0025149:MEDULLOBLASTOMA (Medulloblastoma) [Neoplastic Process]
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0750484:Confirmed (Confirmation) [Finding]
#    790   C0278510:Medulloblastoma (Childhood Medulloblastoma) [Neoplastic Process]
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0750484:Confirmed (Confirmation) [Finding]
#    790   C0278876:Medulloblastoma (Adult Medulloblastoma) [Neoplastic Process]
# Meta Mapping (851):
#    623   C0205462:Histologically (Histologic) [Functional Concept]
#    623   C0750484:Confirmed (Confirmation) [Finding]
#    790   C4330668:Medulloblastoma, Not Otherwise Specified [Neoplastic Process]
# Processing USER.tx.1: oral hormonal contraceptive use
#
# Phrase: oral hormonal contraceptive use
# Meta Mapping (916):
#    881   C0240604:Oral contraceptive use (birth control pill use) [Finding]
#    604   C0458083:Hormonal [Qualitative Concept]
# Meta Mapping (916):
#    701   C0009907:Hormonal Oral contraceptive (Contraceptives, Oral, Hormonal) [Pharmacologic Substance]
#    770   C0042153:use (utilization qualifier) [Functional Concept]
# Meta Mapping (916):
#    701   C0009907:Hormonal Oral contraceptive (Contraceptives, Oral, Hormonal) [Pharmacologic Substance]
#    770   C0457083:Use (Usage) [Functional Concept]
# Meta Mapping (916):
#    701   C0009907:Hormonal Oral contraceptive (Contraceptives, Oral, Hormonal) [Pharmacologic Substance]
#    770   C1947944:Use (Use - dosing instruction imperative) [Intellectual Product]
# Processing USER.tx.1: intra-abdominal infection
#
# Phrase: intra-abdominal infection
# Meta Mapping (1000):
#   1000   C1112209:Intraabdominal Infection (Abdominal Infection) [Disease or Syndrome]
# Processing USER.tx.1: carcinoma neuroendocrine skin
#
# Phrase: carcinoma neuroendocrine skin
# Meta Mapping (1000):
#   1000   C0007129:carcinoma neuroendocrine skin (Merkel cell carcinoma) [Neoplastic Process]
# Processing USER.tx.1: pain, chronic postsurgical
#
# Phrase: pain, chronic postsurgical
# Meta Mapping (1000):
#   1000   C2074900:Postsurgical Pain, Chronic (Postoperative Pain, Chronic) [Disease or Syndrome]
# Processing USER.tx.1: high-risk smoldering multiple myeloma
#
# Phrase: high-risk smoldering multiple myeloma
# Meta Mapping (893):
#    640   C0332167:high risk (High risk of) [Finding]
#    862   C1531608:Smouldering multiple myeloma (Smoldering myeloma) [Neoplastic Process]
# Meta Mapping (893):
#    640   C3272283:High Risk (American College of Cardiology/American Heart Association Lesion Complexity Score C) [Finding]
#    862   C1531608:Smouldering multiple myeloma (Smoldering myeloma) [Neoplastic Process]
# Meta Mapping (893):
#    640   C4050568:High Risk (High Risk Acute Leukemia) [Finding]
#    862   C1531608:Smouldering multiple myeloma (Smoldering myeloma) [Neoplastic Process]
# Meta Mapping (893):
#    640   C4319571:HIGH RISK (High risk) [Finding]
#    862   C1531608:Smouldering multiple myeloma (Smoldering myeloma) [Neoplastic Process]
# Meta Mapping (893):
#    640   C5202936:High Risk (IPSS-R Risk Category High) [Finding]
#    862   C1531608:Smouldering multiple myeloma (Smoldering myeloma) [Neoplastic Process]
# Meta Mapping (893):
#    640   C5202937:High Risk (International Prognostic Index High Risk Group) [Finding]
#    862   C1531608:Smouldering multiple myeloma (Smoldering myeloma) [Neoplastic Process]
# Meta Mapping (893):
#    640   C5238223:High Risk (Disease Risk Index High Risk) [Intellectual Product]
#    862   C1531608:Smouldering multiple myeloma (Smoldering myeloma) [Neoplastic Process]
# Processing USER.tx.1: parent child interactions
#
# Phrase: parent child interactions
# Meta Mapping (988):
#    988   C0030542:parent child interaction (Parent-Child Relationship) [Social Behavior]
# Processing USER.tx.1: metastatic neuroendocrine carcinoma
#
# Phrase: metastatic neuroendocrine carcinoma
# Meta Mapping (1000):
#   1000   C3203639:Metastatic Neuroendocrine Carcinoma (Neuroendocrine carcinoma, metastatic) [Neoplastic Process]
# Processing USER.tx.1: morphinan opioid overdose
#
# Phrase: morphinan opioid overdose
# Meta Mapping (1000):
#   1000   C0572061:Morphinan opioid overdose [Injury or Poisoning]
# Processing USER.tx.1: large bowel cancer
#
# Phrase: large bowel cancer
# Meta Mapping (1000):
#   1000   C0009402:Large Bowel Cancer (Colorectal Carcinoma) [Neoplastic Process]
# Meta Mapping (1000):
#   1000   C0346629:large bowel cancer (Malignant neoplasm of large intestine) [Neoplastic Process]
# Processing USER.tx.1: pancreas divisum
#
# Phrase: pancreas divisum
# Meta Mapping (1000):
#   1000   C0266270:Pancreas divisum [Congenital Abnormality]
# Processing USER.tx.1: relationship, social
#
# Phrase: relationship, social
# Meta Mapping (1000):
#   1000   C0021797:Social Relationship (Interpersonal Relations) [Social Behavior]
# Processing USER.tx.1: complete spinal cord injuries
#
# Phrase: complete spinal cord injuries
# Meta Mapping (983):
#    983   C3544168:Complete spinal cord injury [Injury or Poisoning]
# Processing USER.tx.1: nerve block/methods
#
# Phrase: nerve block/methods
# Meta Mapping (901):
#    716   C0027741:Nerve Block [Therapeutic or Preventive Procedure]
#    790   C0025663:Methods [Intellectual Product]
# Meta Mapping (901):
#    716   C0027741:Nerve Block [Therapeutic or Preventive Procedure]
#    790   C0025664:METHODS (Methods aspects) [Functional Concept]
# Meta Mapping (901):
#    716   C0027741:Nerve Block [Therapeutic or Preventive Procedure]
#    790   C0449851:Methods (Techniques) [Functional Concept]
# Meta Mapping (901):
#    623   C0027740:NERVE (Nerve) [Body Part, Organ, or Organ Component]
#    882   C2945662:block methods (block technique) [Functional Concept]
# Processing USER.tx.1: stage iv gastric cancer
#
# Phrase: stage iv gastric cancer
# Meta Mapping (1000):
#   1000   C0278498:Stage IV Gastric Cancer (Malignant neoplasm of stomach stage IV) [Neoplastic Process]
# Processing USER.tx.1: myocardial oedema
#
# Phrase: myocardial oedema
# Meta Mapping (888):
#    666   C0027061:Myocardial (Myocardium) [Tissue]
#    833   C0013604:OEDEMA (Edema) [Pathologic Function]
# Meta Mapping (888):
#    666   C0027061:Myocardial (Myocardium) [Tissue]
#    833   C1717255:Edema (Edema:Finding:Point in time:^Patient:Ordinal) [Clinical Attribute]
# Meta Mapping (888):
#    666   C1522564:Myocardial [Spatial Concept]
#    833   C0013604:OEDEMA (Edema) [Pathologic Function]
# Meta Mapping (888):
#    666   C1522564:Myocardial [Spatial Concept]
#    833   C1717255:Edema (Edema:Finding:Point in time:^Patient:Ordinal) [Clinical Attribute]
# Processing USER.tx.1: late preterm infant
#
# Phrase: late preterm infant
# Meta Mapping (1000):
#   1000   C3898619:Late Preterm Infant [Age Group]
# Processing USER.tx.1: complication of gastrostomy
#
# Phrase: complication of gastrostomy
# Meta Mapping (1000):
#   1000   C0587245:Complication of gastrostomy [Pathologic Function]
# Processing USER.tx.1: gastrointestinal bleeding
#
# Phrase: gastrointestinal bleeding
# Meta Mapping (1000):
#   1000   C0017181:gastro intestinal bleeding (Gastrointestinal Hemorrhage) [Pathologic Function]
# Processing USER.tx.1: healthy, reproductive age women
#
# Phrase: healthy, reproductive age women
# Meta Mapping (843):
#    617   C0242667:Reproductive Health [Biomedical Occupation or Discipline]
#    604   C0001779:AGE (Age) [Organism Attribute]
#    770   C0043210:Women (Woman) [Population Group]
# Processing USER.tx.1: otitis
#
# Phrase: otitis
# Meta Mapping (1000):
#   1000   C0029877:OTITIS (Ear Inflammation) [Disease or Syndrome]
# Meta Mapping (1000):
#   1000   C0699744:Otitis (Infection of ear) [Disease or Syndrome]
# Processing USER.tx.1: video assisted thoracoscopy
#
# Phrase: video assisted thoracoscopy
# Meta Mapping (1000):
#   1000   C2923055:Video assisted thoracoscopy [Diagnostic Procedure]
# Processing USER.tx.1: percutaneous coronary interventions
#
# Phrase: percutaneous coronary interventions
# Meta Mapping (1000):
#   1000   C1532338:Percutaneous Coronary Interventions (Percutaneous Coronary Intervention) [Therapeutic or Preventive Procedure]
# Processing USER.tx.1: human papillomavirus (hpv) 16+ relapsed/refractory cancer
#
# Phrase: human papillomavirus (hpv) 16+ relapsed/refractory cancer
# Meta Mapping (873):
#    666   C0999806:Human papilloma virus 16 (Human papillomavirus 16) [Virus]
#    783   C0549379:Relapsed Cancer (Recurrent Carcinoma) [Neoplastic Process]
#    586   C0205269:Refractory (Unresponsive to Treatment) [Functional Concept]
# Meta Mapping (873):
#    666   C0999806:Human papilloma virus 16 (Human papillomavirus 16) [Virus]
#    586   C0205336:relapsed (Relapsing course) [Temporal Concept]
#    790   C0677936:Refractory Cancer (Refractory Malignant Neoplasm) [Neoplastic Process]
# Processing USER.tx.1: locally advanced pancreatic ductal adenocarcinoma (pdac)
#
# Phrase: locally advanced pancreatic ductal adenocarcinoma
# Meta Mapping (1000):
#   1000   C4745272:Locally Advanced Pancreatic Ductal Adenocarcinoma [Neoplastic Process]
# Processing USER.tx.1: sudden death, cardiac
#
# Phrase: sudden death, cardiac
# Meta Mapping (1000):
#   1000   C0085298:Sudden Death, Cardiac (Sudden Cardiac Death) [Pathologic Function]
# Processing USER.tx.1: successful conversion rate of operation
#
# Phrase: successful conversion rate of operation
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C0597535:Successful (Success) [Social Behavior]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C0439836:Conversion (Conversions (qualifier value)) [Functional Concept]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C0871208:Rate (Rating (action)) [Activity]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C0543467:Operation (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3241922:Operation (Operation Activity) [Activity]
# Meta Mapping (733):
#    593   C1272703:Successful [Qualitative Concept]
#    760   C5237007:Conversion (Conversion Mutation) [Cell or Molecular Dysfunction]
#    760   C1521828:Rate [Quantitative Concept]
#    593   C3828701:Operation, Not Otherwise Specified [Activity]
# Processing USER.tx.1: catheter related complication
#
# Phrase: catheter related complication
# Meta Mapping (851):
#    623   C0085590:CATHETER (catheter device) [Medical Device]
#    623   C0439849:Related (Relationships) [Qualitative Concept]
#    790   C0009566:Complication [Pathologic Function]
# Meta Mapping (851):
#    623   C0085590:CATHETER (catheter device) [Medical Device]
#    623   C0439849:Related (Relationships) [Qualitative Concept]
#    790   C2362589:Complication (Complication (attribute)) [Idea or Concept]
# Meta Mapping (851):
#    623   C0085590:CATHETER (catheter device) [Medical Device]
#    623   C0445223:Related (Related personal status) [Finding]
#    790   C0009566:Complication [Pathologic Function]
# Meta Mapping (851):
#    623   C0085590:CATHETER (catheter device) [Medical Device]
#    623   C0445223:Related (Related personal status) [Finding]
#    790   C2362589:Complication (Complication (attribute)) [Idea or Concept]
# Processing USER.tx.1: infant mortality
#
# Phrase: infant mortality
# Meta Mapping (1000):
#   1000   C0021278:Infant Mortality [Quantitative Concept]
# Processing USER.tx.1: influenza prevention
#
# Phrase: influenza prevention
# Meta Mapping (888):
#    666   C0021400:INFLUENZA (Influenza) [Disease or Syndrome]
#    833   C0199176:Prevention (Prophylactic treatment) [Therapeutic or Preventive Procedure]
# Meta Mapping (888):
#    666   C0021400:INFLUENZA (Influenza) [Disease or Syndrome]
#    833   C1706420:PREVENTION (Prevention Study) [Research Activity]
# Meta Mapping (888):
#    666   C0021400:INFLUENZA (Influenza) [Disease or Syndrome]
#    833   C2700409:prevention (prevention aspects) [Qualitative Concept]
# Meta Mapping (888):
#    666   C0021403:INFLUENZA (Influenza virus vaccine) [Immunologic Factor,Pharmacologic Substance]
#    833   C0199176:Prevention (Prophylactic treatment) [Therapeutic or Preventive Procedure]
# Meta Mapping (888):
#    666   C0021403:INFLUENZA (Influenza virus vaccine) [Immunologic Factor,Pharmacologic Substance]
#    833   C1706420:PREVENTION (Prevention Study) [Research Activity]
# Meta Mapping (888):
#    666   C0021403:INFLUENZA (Influenza virus vaccine) [Immunologic Factor,Pharmacologic Substance]
#    833   C2700409:prevention (prevention aspects) [Qualitative Concept]
# Processing USER.tx.1: chronic nasal septum perforation
#
# Phrase: chronic nasal septum perforation
# Meta Mapping (916):
#    604   C0205191:CHRONIC (chronic) [Temporal Concept]
#    909   C0235761:NASAL SEPTUM PERFORATION (Perforation of nasal septum) [Anatomical Abnormality]
# Processing USER.tx.1: inclusion on clinical criteria of the syndrome
#
# Phrase: inclusion on clinical criteria of the syndrome
# Meta Mapping (692):
#    774   C1512693:Inclusion Criteria (Inclusion) [Qualitative Concept]
#    581   C0205210:Clinical [Qualitative Concept]
#    581   C0039082:Syndrome [Disease or Syndrome]
# Meta Mapping (692):
#    774   C1512693:Inclusion Criteria (Inclusion) [Qualitative Concept]
#    581   C0205210:Clinical [Qualitative Concept]
#    581   C5238705:Syndrome (Genetic Syndrome Associated with Congenital Heart Defect) [Disease or Syndrome]
# Meta Mapping (692):
#    748   C0007637:INCLUSION (Inclusion Bodies) [Cell Component]
#    581   C0243161:Criteria (criteria) [Idea or Concept]
#    607   C0221444:syndrome clinical (clinical syndromes) [Disease or Syndrome]
# Meta Mapping (692):
#    748   C1512693:INCLUSION (Inclusion) [Qualitative Concept]
#    581   C0243161:Criteria (criteria) [Idea or Concept]
#    607   C0221444:syndrome clinical (clinical syndromes) [Disease or Syndrome]
# Processing USER.tx.1: de novo kidney transplant
#
# Phrase: de novo kidney transplant
# Meta Mapping (888):
#    666   C1515568:De novo (de novo) [Idea or Concept]
#    833   C0022671:KIDNEY TRANSPLANT (Kidney Transplantation) [Therapeutic or Preventive Procedure]
# Processing USER.tx.1: obese older adults
#
# Phrase: obese older adults
# Meta Mapping (901):
#    623   C0028754:OBESE (Obesity) [Disease or Syndrome]
#    882   C0001792:Older Adults (Elderly (population group)) [Population Group]
# Processing USER.tx.1: high frequency jet ventilation
#
# Phrase: high frequency jet ventilation
# Meta Mapping (1000):
#   1000   C0019540:High frequency jet ventilation (High-Frequency Jet Ventilation) [Therapeutic or Preventive Procedure]
# Processing USER.tx.1: choroidal osteoma, bilateral
#
# Phrase: choroidal osteoma, bilateral
# Meta Mapping (1000):
#   1000   C1861558:CHOROIDAL OSTEOMA, BILATERAL (Choroidal Osteoma, Bilateral) [Disease or Syndrome]
# Processing USER.tx.1: early surgery
#
# Phrase: early surgery
# Meta Mapping (888):
#    666   C1279919:Early [Temporal Concept]
#    833   C0038894:Surgery (Surgery specialty) [Biomedical Occupation or Discipline]
# Meta Mapping (888):
#    666   C1279919:Early [Temporal Concept]
#    833   C0038895:surgery (Surgical aspects) [Functional Concept]
# Meta Mapping (888):
#    666   C1279919:Early [Temporal Concept]
#    833   C0543467:Surgery (Operative Surgical Procedures) [Therapeutic or Preventive Procedure]
# Meta Mapping (888):
#    666   C1279919:Early [Temporal Concept]
#    833   C1274039:Surgery (General surgery specialty) [Biomedical Occupation or Discipline]
# Processing USER.tx.1: mitochondrial dna mutation
#
# Phrase: mitochondrial dna mutation
# Meta Mapping (901):
#    858   C2315666:Mitochondrial mutation [Genetic Function]
#    623   C0012854:DNA [Biologically Active Substance,Nucleic Acid, Nucleoside, or Nucleotide]
# Meta Mapping (901):
#    858   C2315666:Mitochondrial mutation [Genetic Function]
#    623   C4521340:DNA (Deoxyribonucleic Acid Measurement) [Laboratory Procedure]
# Meta Mapping (901):
#    716   C0012929:DNA, Mitochondrial [Biologically Active Substance,Nucleic Acid, Nucleoside, or Nucleotide]
#    790   C0026882:Mutation [Genetic Function]
# Meta Mapping (901):
#    716   C0012929:DNA, Mitochondrial [Biologically Active Substance,Nucleic Acid, Nucleoside, or Nucleotide]
#    790   C1705285:Mutation (Mutation Abnormality) [Cell or Molecular Dysfunction]
# Meta Mapping (901):
#    716   C1819717:mitochondrial DNA (mitochondrial DNA location) [Cell Component]
#    790   C0026882:Mutation [Genetic Function]
# Meta Mapping (901):
#    716   C1819717:mitochondrial DNA (mitochondrial DNA location) [Cell Component]
#    790   C1705285:Mutation (Mutation Abnormality) [Cell or Molecular Dysfunction]
# Processing USER.tx.1: her2-negative early breast cancer
#
# Phrase: her2-negative early breast cancer
# Meta Mapping (928):
#    891   C4733095:HER2-negative breast cancer [Neoplastic Process]
#    760   C1279919:Early [Temporal Concept]
# Processing USER.tx.1: elective knee surgery
#
# Phrase: elective knee surgery
# Meta Mapping (901):
#    858   C0206058:Elective Surgery (Elective Surgical Procedures) [Therapeutic or Preventive Procedure]
#    623   C0022742:Knee [Body Part, Organ, or Organ Component]
# Meta Mapping (901):
#    858   C0206058:Elective Surgery (Elective Surgical Procedures) [Therapeutic or Preventive Procedure]
#    623   C0022745:Knee (Knee joint) [Body Space or Junction]
# Meta Mapping (901):
#    858   C0206058:Elective Surgery (Elective Surgical Procedures) [Therapeutic or Preventive Procedure]
#    623   C1963703:Knee, NOS (Knee region structure) [Body Location or Region]
# Meta Mapping (901):
#    623   C0206058:ELECTIVE (Elective Surgical Procedures) [Therapeutic or Preventive Procedure]
#    882   C0187769:knee surgery (Operative procedure on knee) [Therapeutic or Preventive Procedure]
# Meta Mapping (901):
#    623   C0439608:Elective (elective) [Temporal Concept]
#    882   C0187769:knee surgery (Operative procedure on knee) [Therapeutic or Preventive Procedure]
# Processing USER.tx.1: periorbital
#
# Phrase: periorbital
# Meta Mapping (1000):
#   1000   C0230064:Periorbital (Periorbital region) [Body Location or Region]
# Processing USER.tx.1: pulmonary venous stenosis
#
# Phrase: pulmonary venous stenosis
# Meta Mapping (1000):
#   1000   C4280802:Pulmonary venous stenosis (Pulmonary venous occlusion) [Finding]
# Processing USER.tx.1: nose; deformity, syphilitic, congenital
#
# Phrase: nose; deformity, syphilitic, congenital
# Meta Mapping (902):
#    604   C0443319:Syphilitic [Functional Concept]
#    863   C0265736:Congenital nasal deformity (Congenital anomaly of nose) [Congenital Abnormality]
# Processing USER.tx.1: visual acuity reduced transiently
#
# Phrase: visual acuity reduced transiently
# Meta Mapping (909):
#    881   C0234632:Reduced visual acuity [Finding]
# Processing USER.tx.1: tumor in upper gastrointestinal canal or patients with colorectal cancer
#
# Phrase: tumor in upper gastrointestinal canal or patients with colorectal cancer
# Meta Mapping (701):
#    777   C0679342:upper gastrointestinal tumor (upper GI neoplasm) [Neoplastic Process]
#    573   C0086881:Canal (Pulp Canals) [Body Space or Junction]
#    573   C0030705:Patients [Patient or Disabled Group]
#    593   C0009402:Colorectal Cancer (Colorectal Carcinoma) [Neoplastic Process]
# Meta Mapping (701):
#    777   C0679342:upper gastrointestinal tumor (upper GI neoplasm) [Neoplastic Process]
#    573   C0086881:Canal (Pulp Canals) [Body Space or Junction]
#    573   C0030705:Patients [Patient or Disabled Group]
#    593   C2984278:Colorectal cancer (Colorectal Cancer Pathway) [Conceptual Entity]
# Meta Mapping (701):
#    777   C0679342:upper gastrointestinal tumor (upper GI neoplasm) [Neoplastic Process]
#    573   C0086881:Canal (Pulp Canals) [Body Space or Junction]
# ...
#
# Phrase: functional decline and complications of frail older patients admitted to hospital
# Meta Mapping (526):
#    571   C0205245:Functional [Functional Concept]
#    571   C0009566:Complications (Complication) [Pathologic Function]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0021562:Hospital patients (inpatient) [Patient or Disabled Group]
# Meta Mapping (526):
#    571   C0205245:Functional [Functional Concept]
#    571   C0009566:Complications (Complication) [Pathologic Function]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0239966:hospital patients (Hospital patient (finding)) [Finding]
# Meta Mapping (526):
#    571   C0205245:Functional [Functional Concept]
#    571   C1171258:complications (Complication Aspects) [Functional Concept]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0021562:Hospital patients (inpatient) [Patient or Disabled Group]
# Meta Mapping (526):
#    571   C0205245:Functional [Functional Concept]
#    571   C1171258:complications (Complication Aspects) [Functional Concept]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0239966:hospital patients (Hospital patient (finding)) [Finding]
# Meta Mapping (526):
#    571   C0542341:Functional (Function (attribute)) [Functional Concept]
#    571   C0009566:Complications (Complication) [Pathologic Function]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0021562:Hospital patients (inpatient) [Patient or Disabled Group]
# Meta Mapping (526):
#    571   C0542341:Functional (Function (attribute)) [Functional Concept]
#    571   C0009566:Complications (Complication) [Pathologic Function]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0239966:hospital patients (Hospital patient (finding)) [Finding]
# Meta Mapping (526):
#    571   C0542341:Functional (Function (attribute)) [Functional Concept]
#    571   C1171258:complications (Complication Aspects) [Functional Concept]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0021562:Hospital patients (inpatient) [Patient or Disabled Group]
# Meta Mapping (526):
#    571   C0542341:Functional (Function (attribute)) [Functional Concept]
#    571   C1171258:complications (Complication Aspects) [Functional Concept]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0239966:hospital patients (Hospital patient (finding)) [Finding]
# Meta Mapping (526):
#    571   C2700217:Functional (Functional Relationship) [Conceptual Entity]
#    571   C0009566:Complications (Complication) [Pathologic Function]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0021562:Hospital patients (inpatient) [Patient or Disabled Group]
# Meta Mapping (526):
#    571   C2700217:Functional (Functional Relationship) [Conceptual Entity]
#    571   C0009566:Complications (Complication) [Pathologic Function]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0239966:hospital patients (Hospital patient (finding)) [Finding]
# Meta Mapping (526):
#    571   C2700217:Functional (Functional Relationship) [Conceptual Entity]
#    571   C1171258:complications (Complication Aspects) [Functional Concept]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0021562:Hospital patients (inpatient) [Patient or Disabled Group]
# Meta Mapping (526):
#    571   C2700217:Functional (Functional Relationship) [Conceptual Entity]
#    571   C1171258:complications (Complication Aspects) [Functional Concept]
#    571   C0871754:Frail [Finding]
#    538   C0580836:Old [Temporal Concept]
#    589   C4482331:Admitted to [Health Care Activity]
#    587   C0239966:hospital patients (Hospital patient (finding)) [Finding]
# Processing USER.tx.1: irritation potential of topic agent
#
# Phrase: irritation potential of topic agent
# Meta Mapping (734):
#    593   C0441723:Irritation [Phenomenon or Process]
#    760   C3245505:Potential [Qualitative Concept]
#    604   C1710439:Topical agent (Topical Dosage Form) [Biomedical or Dental Material]
# Meta Mapping (734):
#    593   C1706307:Irritation (Irritation (finding)) [Finding]
#    760   C3245505:Potential [Qualitative Concept]
#    604   C1710439:Topical agent (Topical Dosage Form) [Biomedical or Dental Material]
# Meta Mapping (734):
#    593   C2700617:Irritation (Irritation - emotion) [Mental Process]
#    760   C3245505:Potential [Qualitative Concept]
#    604   C1710439:Topical agent (Topical Dosage Form) [Biomedical or Dental Material]
# Processing USER.tx.1: kidney transplant rejection
#
# Phrase: kidney transplant rejection
# Meta Mapping (1000):
#   1000   C0238217:Kidney Transplant Rejection (Renal transplant rejection) [Pathologic Function]
# Processing USER.tx.1: exercise reinforcement
#
# Phrase: exercise reinforcement
# Meta Mapping (888):
#    666   C0015259:Exercise [Daily or Recreational Activity]
#    833   C0035007:reinforcement (Psychological reinforcement) [Mental Process]
# Meta Mapping (888):
#    666   C0015259:Exercise [Daily or Recreational Activity]
#    833   C0678211:Reinforcement, NOS (Reinforcement surgical repair) [Therapeutic or Preventive Procedure]
# Meta Mapping (888):
#    666   C1522704:Exercise (Exercise Pain Management) [Therapeutic or Preventive Procedure]
#    833   C0035007:reinforcement (Psychological reinforcement) [Mental Process]
# Meta Mapping (888):
#    666   C1522704:Exercise (Exercise Pain Management) [Therapeutic or Preventive Procedure]
#    833   C0678211:Reinforcement, NOS (Reinforcement surgical repair) [Therapeutic or Preventive Procedure]
# Processing USER.tx.1: stoma site incisional hernia
#
# Phrase: stoma site incisional hernia
# Meta Mapping (888):
#    666   C1955856:Stoma site (Surgical Stoma) [Anatomical Structure]
#    833   C0267716:Hernia, incisional (Incisional hernia) [Pathologic Function]
# Processing USER.tx.1: post menopaused female
#
# Phrase: post menopaused female
# Meta Mapping (746):
#    623   C0687676:Post [Temporal Concept]
#    790   C0043210:female (Woman) [Population Group]
# Meta Mapping (746):
#    623   C0687676:Post [Temporal Concept]
#    790   C0086287:FEMALE (Females) [Organism Attribute]
# Meta Mapping (746):
#    623   C0687676:Post [Temporal Concept]
#    790   C1705497:Female (Female, Self-Report) [Qualitative Concept]
# Meta Mapping (746):
#    623   C0687676:Post [Temporal Concept]
#    790   C1705498:FEMALE (Female Phenotype) [Qualitative Concept]
# Meta Mapping (746):
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    790   C0043210:female (Woman) [Population Group]
# Meta Mapping (746):
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    790   C0086287:FEMALE (Females) [Organism Attribute]
# Meta Mapping (746):
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    790   C1705497:Female (Female, Self-Report) [Qualitative Concept]
# Meta Mapping (746):
#    623   C1704687:Post (Post Device) [Manufactured Object]
#    790   C1705498:FEMALE (Female Phenotype) [Qualitative Concept]
# Meta Mapping (746):
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    790   C0043210:female (Woman) [Population Group]
# Meta Mapping (746):
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    790   C0086287:FEMALE (Females) [Organism Attribute]
# Meta Mapping (746):
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    790   C1705497:Female (Female, Self-Report) [Qualitative Concept]
# Meta Mapping (746):
#    623   C3469826:POST (SLC35G1 gene) [Gene or Genome]
#    790   C1705498:FEMALE (Female Phenotype) [Qualitative Concept]
# Processing USER.tx.1: drug-drug interaction (ddi)
#
# Phrase: drug-drug interaction
# Meta Mapping (1000):
#   1000   C0687133:Drug drug interaction (Drug Interactions) [Pathologic Function]
# Meta Mapping (1000):
#   1000   C4761504:DRUG-DRUG INTERACTION (Drug-Drug Interaction Study) [Research Activity]
# Processing USER.tx.1: castleman's disease, multicentric
#
# Phrase: castleman's disease, multicentric
# Meta Mapping (1000):
#   1000   C1334815:Multicentric Castleman's Disease (Multi-centric Castleman's Disease) [Neoplastic Process]
# Processing USER.tx.1: heart insufficiency
#
# Phrase: heart insufficiency
# Meta Mapping (1000):
#   1000   C0018801:heart insufficiency (Heart failure) [Disease or Syndrome]
# Processing USER.tx.1: lipoproteins
#
# Phrase: lipoproteins
# Meta Mapping (1000):
#   1000   C0023820:Lipoproteins [Amino Acid, Peptide, or Protein,Biologically Active Substance]
# Processing USER.tx.1: epidermylosis bullosa
#
# Phrase: epidermylosis bullosa
# Processing USER.tx.1: secondary malignant neoplasm of bone
#
# Phrase: secondary malignant neoplasm of bone
# Meta Mapping (1000):
#   1000   C0153690:Secondary malignant neoplasm of bone [Neoplastic Process]
# Processing USER.tx.1: ambulatory surgery programmed
#
# Phrase: ambulatory surgery programmed
# Meta Mapping (882):
#    882   C0002428:Ambulatory surgery (Ambulatory Surgical Procedures) [Therapeutic or Preventive Procedure]
# Processing USER.tx.1: behavioral measures of tolerance
#
# Phrase: behavioral measures of tolerance
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C0079809:Measures [Quantitative Concept]
#    604   C0013220:Tolerance (Drug Tolerance) [Finding]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C0079809:Measures [Quantitative Concept]
#    604   C0020963:Tolerance (Immune Tolerance) [Pathologic Function]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C0079809:Measures [Quantitative Concept]
#    604   C0220929:tolerance (Mental tolerance) [Mental Process]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C0079809:Measures [Quantitative Concept]
#    604   C0231197:TOLERANCE (Physiologic tolerance) [Physiologic Function]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C0079809:Measures [Quantitative Concept]
#    604   C1704410:Tolerance [Qualitative Concept]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C1879489:Measures (Measures (attribute)) [Functional Concept]
#    604   C0013220:Tolerance (Drug Tolerance) [Finding]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C1879489:Measures (Measures (attribute)) [Functional Concept]
#    604   C0020963:Tolerance (Immune Tolerance) [Pathologic Function]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C1879489:Measures (Measures (attribute)) [Functional Concept]
#    604   C0220929:tolerance (Mental tolerance) [Mental Process]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C1879489:Measures (Measures (attribute)) [Functional Concept]
#    604   C0231197:TOLERANCE (Physiologic tolerance) [Physiologic Function]
# Meta Mapping (733):
#    604   C0004927:Behavioral (Behavior) [Behavior]
#    770   C1879489:Measures (Measures (attribute)) [Functional Concept]
#    604   C1704410:Tolerance [Qualitative Concept]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [175], in <cell line: 20>()
#      28 if response.status_code == 302:
#      29     newurl = s.get_redirect_target(response)
# ---> 30     response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)
#      31 print(response.text)
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/requests/sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     624 def post(self, url, data=None, json=None, **kwargs):
#     625     r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627     :param url: URL for the new :class:`Request` object.
#    (...)
#     632     :rtype: requests.Response
#     633     """
# --> 635     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/requests/sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/urllib3/response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     559 """
#     560 A generator wrapper for the read() method. A call will block until
#     561 ``amt`` bytes have been read from the connection or until the
#    (...)
#     572     'content-encoding' header.
#     573 """
#     574 if self.chunked and self.supports_chunked_reads():
# --> 575     for line in self.read_chunked(amt, decode_content=decode_content):
#     576         yield line
#     577 else:
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/urllib3/response.py:767, in HTTPResponse.read_chunked(self, amt, decode_content)
#     764     return
#     766 while True:
# --> 767     self._update_chunk_length()
#     768     if self.chunk_left == 0:
#     769         break
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/urllib3/response.py:697, in HTTPResponse._update_chunk_length(self)
#     695 if self.chunk_left is not None:
#     696     return
# --> 697 line = self._fp.fp.readline()
#     698 line = line.split(b";", 1)[0]
#     699 try:
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # TRY FUZZY MAPPING USING BOTH CANDIDATES FROM METAMAP AND MESH

# %%
conditions_unmapped_per_study
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000110                                          [obesity]
# NCT00000112                                [diabetes, obesity]
# NCT00000115                           [macular edema, cystoid]
# ...                                                        ...
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794048                [pancreatic tumor, hepatocarcinoma]
# NCT05794061  [psychiatric disorder, dementia, cognitive imp...
# NCT05794074  [nutrition deficiency (xanth deficiency) due t...
# NCT05794087                                    [air pollution]
#
#              condition_counts
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000110                 1
# NCT00000112                 2
# NCT00000115                 1
# ...                       ...
# NCT05794035                 1
# NCT05794048                 2
# NCT05794061                 3
# NCT05794074                 1
# NCT05794087                 1
#
# [344498 rows x 2 columns]

# %%
condition_mesh_leaves
# Out:
#                 id       nct_id             mesh_term    downcase_mesh_term  \
# 0        113697939  NCT00185796              Syndrome              syndrome
# 2        113698185  NCT03516604            Depression            depression
# 5        113698730  NCT00461539            Depression            depression
# 6        113698920  NCT05324137                Polyps                polyps
# 11       113700140  NCT00176514             Mucositis             mucositis
# ...            ...          ...                   ...                   ...
# 2849547  111234990  NCT00733525       Bulimia Nervosa       bulimia nervosa
# 2849551  111234994  NCT02653131  Short Bowel Syndrome  short bowel syndrome
# 2849552  111234995  NCT02653131              Syndrome              syndrome
# 2849564  111204205  NCT04834908            Infections            infections
# 2849565  111204206  NCT04834908              COVID-19              covid-19
#
#          mesh_type
# 0        mesh-list
# 2        mesh-list
# 5        mesh-list
# 6        mesh-list
# 11       mesh-list
# ...            ...
# 2849547  mesh-list
# 2849551  mesh-list
# 2849552  mesh-list
# 2849564  mesh-list
# 2849565  mesh-list
#
# [761406 rows x 5 columns]

# %%
# merge all available MeSH terms for each condition (that is still unmapped)
condition_mesh_terms_per_study = pd.DataFrame(condition_mesh_leaves[["nct_id", "downcase_mesh_term"]].groupby("nct_id")["downcase_mesh_term"].apply(list))
condition_mesh_terms_per_study
# Out:
#                                             downcase_mesh_term
# nct_id
# NCT00000102  [adrenal hyperplasia, congenital, adrenogenita...
# NCT00000104                        [poisoning, lead poisoning]
# NCT00000105                                          [tetanus]
# NCT00000106            [rheumatic diseases, collagen diseases]
# NCT00000107  [heart defects, congenital, congenital abnorma...
# ...                                                        ...
# NCT05793996                          [anemia, iron-deficiency]
# NCT05794022                [myocardial infarction, infarction]
# NCT05794035                                   [skin neoplasms]
# NCT05794048  [pancreatic neoplasms, carcinoma, hepatocellular]
# NCT05794061               [mental disorders, problem behavior]
#
# [370170 rows x 1 columns]

# %%
unmapped_condition_candidates = pd.merge(conditions_unmapped_per_study, condition_mesh_terms_per_study, left_on=["nct_id"], right_on=["nct_id"])
unmapped_condition_candidates
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000112                                [diabetes, obesity]
# NCT00000115                           [macular edema, cystoid]
# NCT00000123                                           [myopia]
# ...                                                        ...
# NCT05793983  [liver failure, acute on chronic, infections, ...
# NCT05793996   [chronic heart failure, iron deficiency, latent]
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794048                [pancreatic tumor, hepatocarcinoma]
# NCT05794061  [psychiatric disorder, dementia, cognitive imp...
#
#              condition_counts  \
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000112                 2
# NCT00000115                 1
# NCT00000123                 1
# ...                       ...
# NCT05793983                 5
# NCT05793996                 2
# NCT05794035                 1
# NCT05794048                 2
# NCT05794061                 3
#
#                                             downcase_mesh_term
# nct_id
# NCT00000102  [adrenal hyperplasia, congenital, adrenogenita...
# NCT00000105                                          [tetanus]
# NCT00000112        [acanthosis nigricans, glucose intolerance]
# NCT00000115                             [macular edema, edema]
# NCT00000123                                      [astigmatism]
# ...                                                        ...
# NCT05793983  [liver cirrhosis, liver diseases, liver failur...
# NCT05793996                          [anemia, iron-deficiency]
# NCT05794035                                   [skin neoplasms]
# NCT05794048  [pancreatic neoplasms, carcinoma, hepatocellular]
# NCT05794061               [mental disorders, problem behavior]
#
# [268411 rows x 3 columns]

# %%
# FOLLOW THIS TUTORIAL:
https://www.datacamp.com/tutorial/fuzzy-string-python

# %%
single_mapped_conditions = condition_mesh_leaves[condition_mesh_leaves.nct_id.isin(unmapped_single_conditions.index)]
single_mapped_conditions
# Out:
#                 id       nct_id        mesh_term downcase_mesh_term  mesh_type
# 0        113697939  NCT00185796         Syndrome           syndrome  mesh-list
# 2        113698185  NCT03516604       Depression         depression  mesh-list
# 5        113698730  NCT00461539       Depression         depression  mesh-list
# 6        113698920  NCT05324137           Polyps             polyps  mesh-list
# 14       113700556  NCT00165893        Back Pain          back pain  mesh-list
# ...            ...          ...              ...                ...        ...
# 2849543  111234985  NCT00733447    Heart Failure      heart failure  mesh-list
# 2849546  111234988  NCT00733525          Bulimia            bulimia  mesh-list
# 2849547  111234990  NCT00733525  Bulimia Nervosa    bulimia nervosa  mesh-list
# 2849564  111204205  NCT04834908       Infections         infections  mesh-list
# 2849565  111204206  NCT04834908         COVID-19           covid-19  mesh-list
#
# [334305 rows x 5 columns]

# %%
# add the single MeSH term that exists for studies with only 1 condition listed
single_mapped_conditions = pd.merge(conditions_unmapped, unmapped_single_conditions, left_on=['nct_id'], right_on = ['nct_id'])
single_mapped_conditions
# Out:
#              nct_id                                               name  \
# 0       NCT00000102                     Congenital Adrenal Hyperplasia
# 1       NCT00000105                                             Cancer
# 2       NCT00000110                                            Obesity
# 3       NCT00000115                             Macular Edema, Cystoid
# 4       NCT00000123                                             Myopia
# ...             ...                                                ...
# 241954  NCT05793944                                          Pregnancy
# 241955  NCT05794009                                   Exercise Therapy
# 241956  NCT05794035                          Skin Cancer, Non-Melanoma
# 241957  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 241958  NCT05794087                                      Air Pollution
#
#                                           downcase_name_x mesh_term  \
# 0                          congenital adrenal hyperplasia       NaN
# 1                                                  cancer       NaN
# 2                                                 obesity       NaN
# 3                                  macular edema, cystoid       NaN
# 4                                                  myopia       NaN
# ...                                                   ...       ...
# 241954                                          pregnancy       NaN
# 241955                                   exercise therapy       NaN
# 241956                          skin cancer, non-melanoma       NaN
# 241957  nutrition deficiency (xanth deficiency) due to...       NaN
# 241958                                      air pollution       NaN
#
#        downcase_mesh_term mesh_type  \
# 0                     NaN       NaN
# 1                     NaN       NaN
# 2                     NaN       NaN
# 3                     NaN       NaN
# 4                     NaN       NaN
# ...                   ...       ...
# 241954                NaN       NaN
# 241955                NaN       NaN
# 241956                NaN       NaN
# 241957                NaN       NaN
# 241958                NaN       NaN
#
#                                           downcase_name_y  condition_counts
# 0                        [congenital adrenal hyperplasia]                 1
# 1                                                [cancer]                 1
# 2                                               [obesity]                 1
# 3                                [macular edema, cystoid]                 1
# 4                                                [myopia]                 1
# ...                                                   ...               ...
# 241954                                        [pregnancy]                 1
# 241955                                 [exercise therapy]                 1
# 241956                        [skin cancer, non-melanoma]                 1
# 241957  [nutrition deficiency (xanth deficiency) due t...                 1
# 241958                                    [air pollution]                 1
#
# [241959 rows x 8 columns]

# %%
# what are the MeSH terms for a study with exactly 1 condition listed. Are there any clinical trials with only 1 condition where there's only 1 MeSH term for it?
condition_mesh_leaves_per_study = pd.DataFrame(condition_mesh_leaves[["nct_id", "downcase_mesh_term"]].groupby('nct_id')['downcase_mesh_term'].apply(list))
condition_mesh_leaves_per_study['mesh_leaf_list_count'] = condition_mesh_leaves_per_study['downcase_mesh_term'].str.len()
singular_condition_mesh_leaves = condition_mesh_leaves_per_study.loc[condition_mesh_leaves_per_study["mesh_leaf_list_count"] == 1] 
single_conditions = singular_condition_mesh_leaves['downcase_mesh_term'].str.get(0)

single_conditions

# %%
# find the studies with only 1 condition listed, and merge the studies with only one term listed with the condition_mesh_leaves with only 1 
conditions_single_mapped = pd.merge(conditions_unmapped, single_conditions, left_on=['nct_id'], right_on = ['nct_id'])
conditions_single_mapped[:20]
